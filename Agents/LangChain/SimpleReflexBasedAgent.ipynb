# %% [markdown]
# # AI Agent: Simple Reflex Based Agent

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# !pip3 install -qU langchain langgraph openai ipython-autotime
# %load_ext autotime
# Out:
# ...
# time: 157 μs (started: 2025-05-26 16:51:39 -07:00)
