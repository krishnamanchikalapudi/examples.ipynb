# %% [markdown]
# # One-Hot Encoding
#
# One-hot encoding is a method to convert categorical data into a binary matrix (0s and 1s), where each column represents one category.
#
# Example:
# If categories are: ["Red", "Green", "Blue"]
# - "Red" becomes [1, 0, 0]
# - "Green" becomes [0, 1, 0]
# - "Blue" becomes [0, 0, 1]
# """)

# %% [markdown]
# ## Why Use It?
# - ML models only accept numerical input.
# - Label encoding (Red = 0, Green = 1, Blue = 2) might suggest order, which is incorrect for nominal data.
# - One-hot encoding treats each category as independent.

# %% [markdown]
# ### Example using PyTorch

# %%
# %%time
# %pip install -U torch ipython-autotime ipywidgets

# %load_ext autotime
# Out:
# Requirement already satisfied: torch in /opt/homebrew/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: ipython-autotime in /opt/homebrew/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: ipywidgets in /opt/homebrew/lib/python3.11/site-packages (8.1.6)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: ipython in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython-autotime) (8.29.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: decorator in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (2.18.0)
# Requirement already satisfied: stack-data in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-autotime) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-autotime) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-autotime) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-autotime) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from asttokens>=2.1.0->stack-data->ipython->ipython-autotime) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# CPU times: user 6.1 ms, sys: 14.1 ms, total: 20.2 ms
# Wall time: 929 ms
# time: 931 ms (started: 2025-04-16 08:07:45 -07:00)

# %%
# %%time
import torch

# Sample categories
categories = ["Red", "Green", "Blue"]

# Step 1: Create vocabulary 
vocab = {word: idx for idx, word in enumerate(set(categories))}
print("Vocabulary mapping:", vocab)

# Step 2: Convert to indices
indices = torch.tensor([vocab[word] for word in categories])
print("Index tensor:", indices)

# Step 3: One-hot encode using PyTorch
one_hot_encoded = torch.nn.functional.one_hot(indices, num_classes=len(vocab))
print("One-hot encoded tensor:\n", one_hot_encoded)
# Out:
# Vocabulary mapping: {'Red': 0, 'Green': 1, 'Blue': 2}
# Index tensor: tensor([0, 1, 2])
# One-hot encoded tensor:
#  tensor([[1, 0, 0],
#         [0, 1, 0],
#         [0, 0, 1]])
# CPU times: user 1.3 ms, sys: 1.97 ms, total: 3.27 ms
# Wall time: 2.56 ms
# time: 5.05 ms (started: 2025-04-16 08:07:46 -07:00)

# %% [markdown]
# ### Example using Pandas

# %%
# %%time
# %pip install -U pandas ipython-autotime ipywidgets

# %load_ext autotime
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: ipython-autotime in /opt/homebrew/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: ipywidgets in /opt/homebrew/lib/python3.11/site-packages (8.1.6)
# Requirement already satisfied: numpy>=1.23.2 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: ipython in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython-autotime) (8.29.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets) (3.0.14)
# Requirement already satisfied: decorator in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (2.18.0)
# Requirement already satisfied: stack-data in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: six>=1.5 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-autotime) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-autotime) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-autotime) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/krishnam/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython->ipython-autotime) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# CPU times: user 5.87 ms, sys: 11.3 ms, total: 17.2 ms
# Wall time: 928 ms
# time: 928 ms (started: 2025-04-16 08:07:46 -07:00)

# %%
# %%time
import pandas as pd

# Sample categories
categories = ["Red", "Green", "Blue"]

data = pd.DataFrame(categories, columns=["Color"])

# One-hot encode the 'Color' column
one_hot = pd.get_dummies(data["Color"])
print(one_hot)

one_hot = one_hot.astype(int)
print("\nOne-Hot Encoded Data (with 1s and 0s):")
print(one_hot)
# Out:
#     Blue  Green    Red
# 0  False  False   True
# 1  False   True  False
# 2   True  False  False
#
# One-Hot Encoded Data (with 1s and 0s):
#    Blue  Green  Red
# 0     0      0    1
# 1     0      1    0
# 2     1      0    0
# CPU times: user 2.21 ms, sys: 1.58 ms, total: 3.79 ms
# Wall time: 3.68 ms
# time: 4.78 ms (started: 2025-04-16 08:07:47 -07:00)

# %% [markdown]
# ## Pros and Cons
# ### Pros
# - Simple and effective
# - Works well with many models
#
# ### Cons
# - Increases dimensionality (curse of dimensionality)
# - May lead to sparse matrices for high-cardinality features
