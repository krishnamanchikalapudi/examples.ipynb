# %% [markdown]
# # NLP trasformer model

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# %python3 -m pip install --upgrade pip
# Out:
# UsageError: Line magic function `%python3` not found (But cell magic `%%python3` exists, did you mean that instead?).

# %%
# %%time
# %pip install -qU transformers tf-keras numpy ipython-autotime ipywidgets
# %load_ext autotime
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# CPU times: user 15.3 ms, sys: 14.6 ms, total: 30 ms
# Wall time: 1.89 s
# time: 363 μs (started: 2025-05-18 10:51:27 -07:00)

# %%
import numpy as np
from transformers import pipeline
# Out:
# time: 7.28 s (started: 2025-05-18 10:51:27 -07:00)

# %% [markdown]
# ## Load a pre-trained pipeline for sentiment-analysis

# %%
classifier = pipeline(
    task="sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)
# Out:
# Device set to use mps:0
# time: 823 ms (started: 2025-05-18 10:51:34 -07:00)

# %% [markdown]
# ## Provide a simple input text

# %%
input_text = "I love working with Hugging Face models! 🚀"
# Out:
# time: 336 μs (started: 2025-05-18 10:51:35 -07:00)

# %% [markdown]
# ## Get prediction

# %%
result = classifier(input_text)
result
# Out:
# [{'label': 'POSITIVE', 'score': 0.9980546236038208}]
# time: 1.43 s (started: 2025-05-18 10:51:35 -07:00)

# %% [markdown]
# ## Display output

# %%
print(f"Input: {input_text}")
print(f"Prediction: {result}")

label = result[0]['label']
score = result[0]['score']
print(f"\nPredicted Label: {label}")
print(f"Confidence Score: {score:.4f}")
# Out:
# Input: I love working with Hugging Face models! 🚀
# Prediction: [{'label': 'POSITIVE', 'score': 0.9980546236038208}]
#
# Predicted Label: POSITIVE
# Confidence Score: 0.9981
# time: 262 μs (started: 2025-05-18 10:51:36 -07:00)
