# %% [markdown]
# #Tokens

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# ...
# CPU times: user 7.67 ms, sys: 12.6 ms, total: 20.3 ms
# Wall time: 910 ms

# %% [markdown]
# https://pypi.org/project/nltk/

# %%
# %%time

# !pip install -qU transformers nltk tiktoken ipython-autotime ipywidgets

# %load_ext autotime
# Out:
# CPU times: user 6.62 ms, sys: 8.31 ms, total: 14.9 ms
# Wall time: 1.09 s
# time: 351 μs (started: 2025-05-21 14:46:29 -07:00)

# %%
text = "This is a sample sentence to tokenize."
# Out:
# time: 199 μs (started: 2025-05-21 14:46:29 -07:00)

# %% [markdown]
# ## NLTK tokens

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', 'to', 'tokenize', '.']
# time: 1.39 s (started: 2025-05-21 14:46:29 -07:00)
# [nltk_data] Downloading package punkt to /Users/krishnam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Transformer tokens

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.ipynb/Mini-Projects/tokens.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/Mini-Projects/tokens.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> from transformers import AutoTokenizer
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/Mini-Projects/tokens.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/Mini-Projects/tokens.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> tokens = tokenizer.tokenize(text)
#
# File /opt/homebrew/lib/python3.11/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
# ...

# %% [markdown]
# ## OpenAI tiktokens

# %%
import tiktoken

# Choose encoding based on the model you're using
encoding = tiktoken.encoding_for_model("gpt-4")  # or "gpt-3.5-turbo", etc.


# Encode the text to get token IDs
tokens = encoding.encode(text)
print("Token IDs:", tokens)

# Optional: decode tokens back to text
decoded_text = encoding.decode(tokens)
print("Decoded Text:", decoded_text)
