# %% [markdown]
# #Tokens

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# %python3 -m pip install --upgrade pip

# %%
# %%time
# %pip install -qU transformers ntlk tiktoken ipython-autotime ipywidgets
# %load_ext autotime

# %%
text = "This is a sample sentence to tokenize."

# %% [markdown]
# ## NLTK tokens

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)

# %% [markdown]
# ## Transformer tokens

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

tokens = tokenizer.tokenize(text)
print(tokens)

# %% [markdown]
# ## OpenAI tiktokens

# %%
import tiktoken

# Choose encoding based on the model you're using
encoding = tiktoken.encoding_for_model("gpt-4")  # or "gpt-3.5-turbo", etc.


# Encode the text to get token IDs
tokens = encoding.encode(text)
print("Token IDs:", tokens)

# Optional: decode tokens back to text
decoded_text = encoding.decode(tokens)
print("Decoded Text:", decoded_text)
