# %% [markdown]
# # ETF information

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# ...
# CPU times: user 8.65 ms, sys: 10.4 ms, total: 19 ms
# Wall time: 1.28 s

# %%
# %pip install -Uq urllib3 beautifulsoup4 pandas ipython-autotime
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedchain 0.1.128 requires chromadb<0.6.0,>=0.5.10, but you have chromadb 1.0.15 which is incompatible.
# app 0.1.0 requires tenacity<9.0.0,>=8.2.3, but you have tenacity 9.1.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## ETFs list

# %%
etfs_list = [
    "https://investor.vanguard.com/investment-products/list/etfs?filters=open",
    "https://www.schwab.com/research/etfs/tools/schwab-etfs",
    "https://www.nyse.com/listings_directory/etf",
]

etfs_list
# Out:
# ['https://investor.vanguard.com/investment-products/list/etfs?filters=open',
#  'https://www.schwab.com/research/etfs/tools/schwab-etfs']
