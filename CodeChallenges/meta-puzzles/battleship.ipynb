# %% [markdown]
# # Battleship
# Problem: https://www.metacareers.com/profile/coding_puzzles?puzzle=3641006936004915
#
# You're playing Battleship on a grid of cells with `R` rows and `C` columns. There are `0` or more battleships on the grid, each occupying a single distinct cell. The cell in the <I>i</I>th row from the top and <I>j</I>th column from the left either contains a battleship (<I>j</I>th column from the left either contains a battleship (G<sub>i,j</sub> = 1) or doesn't (G<sub>i,j</sub> = 0).
#
# You're going to fire a single shot at a random cell in the grid. You'll choose this cell uniformly at random from the <b>R ∗ C</b> possible cells. You're interested in the probability that the cell hit by your shot contains a battleship.
#
# Your task is to implement the function <b>getHitProbability(R, C, G)</b> which returns this probability.
#
# Note: Your return value must have an absolute or relative error of at most 10<sup>-6</sup> to be considered correct.
#
#
# Example 1:
# ``````
# Input:
# R = 2
# C = 3
# G = 0 0 1
#     1 0 1
# Output: Expected Return Value = 0.50000000
# Explanation: 3 of the 6 cells in the grid contain battleships. Therefore, the probability that your shot will hit one of them is 3/6=0.5.
# ``````
#
# Example 2:
# ``````
# Input:
# R = 2
# C = 2
# G = 1 1
#     1 1
# Output: Expected Return Value = 1.00000000
# ``````
#
# Constraints:
# - 1 ≤ R,C ≤ 100
# - 0 ≤ G<sub>i,j</sub> ≤ 1
#
# Difficulty: <b>Warmup</b>
#
# ### Companies:
# - Meta
# - Facebook
# - Instagram
# - WhatsApp
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:
    def getHitProbability(R: int, C: int, G: List[List[int]]) -> float:

    return 0.0

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(?)</b> and `SPACE complexity` of <b>O(?)</b>

# %% [markdown]
# ## Test cases

# %%
def create_linked_list(values):
    """Helper function to create a linked list from a list of values"""
    if not values:
        return None
    head = ListNode(values[0])
    current = head
    for val in values[1:]:
        current.next = ListNode(val)
        current = current.next
    return head


def linked_list_to_array(head):
    """Helper function to convert linked list to array for testing"""
    result = []
    current = head
    while current:
        result.append(current.val)
        current = current.next
    return result

# %% [markdown]
# ### Functions: Tree

# %%
from typing import (
    Dict,
    List,
    Set,
    Tuple,
) 

def create_tree(values):
    """Create a binary tree from the given input."""
    # Accepts: None -> None, TreeNode -> returned as-is, scalar (int/str) -> single node,
    # or a list representing level-order traversal with `None` for missing nodes.
    if values is None:
        return None
    # If already a TreeNode, return it
    if isinstance(values, TreeNode):
        return values
    # If scalar (int/float/str), create a single node
    if not isinstance(values, list):
        return TreeNode(values)

    # List input: build tree in level order, None indicates missing child
    if len(values) == 0:
        return None
    root = TreeNode(values[0])
    queue = [root]
    i = 1
    while queue and i < len(values):
        node = queue.pop(0)
        # left child
        if i < len(values):
            val = values[i]
            if val is not None:
                node.left = TreeNode(val)
                queue.append(node.left)
            i += 1
        # right child
        if i < len(values):
            val = values[i]
            if val is not None:
                node.right = TreeNode(val)
                queue.append(node.right)
            i += 1
    return root


def tree_to_list(root):
    """Convert a binary tree to a level-order list representation (trim trailing Nones)."""
    if not root:
        return []
    result = []
    queue = [root]
    while queue:
        node = queue.pop(0)
        if node is None:
            result.append(None)
            continue
        result.append(node.val)
        queue.append(node.left)
        queue.append(node.right)
    # remove trailing Nones
    while result and result[-1] is None:
        result.pop()
    return result

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# %%
# Brute Force Test Case
def test_bruteForce(input, target, expected_output):
    sol = BruteForceSolution()
    actual = sol.function(input, target)

    try:
        if isinstance(expected_output, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )

# %%
# Best Solution Test Case
def test_solution(input, target, expected_output):
    sol = Solution()
    actual = sol.function(input, target)

    try:
        if isinstance(expected_output, list):
            assert actual.sort() == expected_output.sort()
            # elif isinstance(expected_output, tuple):
            # elif isinstance(expected_output, dict):
            # elif isinstance(expected_output, set):
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )

# %% [markdown]
# ### test-1

# %%
nums = [2, 7, 11, 15]
target = 9
expected_output = [0, 1]

# %%
test_bruteForce(nums, target, expected_output)

# %%
test_solution(nums, target, expected_output)

# %% [markdown]
# ### test-2

# %%
nums = [3, 2, 4]
target = 6
expected_output = [1, 2]

# %%
test_bruteForce(nums, target, expected_output)

# %%
test_solution(nums, target, expected_output)

# %% [markdown]
# ### test-3

# %%
nums = [3, 3]
target = 6
expected_output = [0, 1]

# %%
test_bruteForce(nums, target, expected_output)

# %%
test_solution(nums, target, expected_output)

# %% [markdown]
# ## Summary
#
# My Submission: <URL>
#
#
# <img src="./submission/?.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
