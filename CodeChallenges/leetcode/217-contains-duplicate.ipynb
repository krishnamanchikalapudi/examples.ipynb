# %% [markdown]
# # 217. Contains Duplicate
#
# Problem: https://leetcode.com/problems/contains-duplicate/
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# Example 1:
# ``````
# Input: [1,2,3,1]
# Output: true
# Explanation: The element 1 occurs at the indices 0 and 3.
# ``````
#
# Example 2:
# ``````
# Input: [1,2,3,4]
# Output: false
# Explanation: All elements are distinct.
# ``````
#
# Example 3:
# ``````
# Input: [1,1,1,3,3,4,3,2,4,2]
# Output: true
#  ``````
#
# Constraints:
# - 1 <= nums.length <= 105
# - 109 <= nums[i] <= 109
#
#
#
# - Interview Questions: https://leetcode.com/studyplan/top-interview-150/

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.13/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# time: 115 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import List


class BruteForceSolution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        """
        :type nums: List[int]
        :rtype: boolean
        """
        for i in range(len(nums)):  # O(n)
            for j in range(i + 1, len(nums)):  # O(n)
                if nums[i] == nums[j]:  # O(1)
                    return True  # O(1)
        return False  # O(1)
# Out:
# time: 413 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# The Brute Force solution has a `TIME complexity` of <b>O(n <sup>2</sup>)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ### BEST

# %%
class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        """
        :type nums: List[int]
        :rtype: boolean
        """
        hashMap = {}  # O(n)
        for i in range(len(nums)):  # O(n)
            num = nums[i]  # O(1)
            if num in hashMap:  # O(1)
                return True  # O(1)
            hashMap[nums[i]] = i  # O(1)

        return False  # O(1)
# Out:
# time: 849 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>
# - Time: each element is visited once
# - Space: storing upto n elements in hashmap

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 4.41 ms (started: 2025-08-14 21:15:43 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(nums, expected_output):
    s = BruteForceSolution()
    actual = s.containsDuplicate(nums)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 270 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
# Best Solution Test Case
def test_solution(nums, expected_output):
    s = Solution()
    actual = s.containsDuplicate(nums)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 361 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# ### test-1

# %%
nums = [1, 2, 3, 1]
expected_output = True
# Out:
# time: 128 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 171 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 376 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# ### test-2

# %%
nums = [1, 2, 3, 4]
expected_output = False
# Out:
# time: 135 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 154 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 290 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# ### test-3

# %%
nums = [1, 1, 1, 3, 3, 4, 3, 2, 4, 2]
expected_output = True
# Out:
# time: 169 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 691 μs (started: 2025-08-14 21:15:43 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 138 μs (started: 2025-08-14 21:15:43 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/contains-duplicate/submissions/1735603920/
# <table>
#  <tr>
# <td><img src="../images/tc-OofN.png"> </td>
# <td><img src="../images/sc-OofN.png"> </td>
# <tr>
# </table>
