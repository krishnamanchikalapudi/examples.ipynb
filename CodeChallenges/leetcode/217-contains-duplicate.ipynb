# %% [markdown]
# # 217. Contains Duplicate
#
# Problem: https://leetcode.com/problems/contains-duplicate/
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# Example 1:
# ``````
# Input: [1,2,3,1]
# Output: true
# Explanation: The element 1 occurs at the indices 0 and 3.
# ``````
#
# Example 2:
# ``````
# Input: [1,2,3,4]
# Output: false
# Explanation: All elements are distinct.
# ``````
#
# Example 3:
# ``````
# Input: [1,1,1,3,3,4,3,2,4,2]
# Output: true
#  ``````
#
# Constraints:
# - 1 <= nums.length <= 105
# - 109 <= nums[i] <= 109
#
#
#
# - Interview Questions: https://leetcode.com/studyplan/top-interview-150/

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime

# %% [markdown]
# ## USE-CASE
# ### Q: Which use-case would the '?' problem be used for?
# #### ????

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
class BruteForceSolution:
    def function(self, nums, target):

        return None  # O(1)

# %% [markdown]
# ### BEST

# %%
class Solution(object):
    def function(self, nums, target):

        return None  # O(1)

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# %%
# Brute Force Test Case
def test_bruteForce_function(nums, target, expected_output):
    s = BruteForceSolution()
    actual = s.function(nums, target)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )

# %%
# Best Solution Test Case
def test_function(nums, target, expected_output):
    s = Solution()
    actual = s.function(nums, target)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )

# %% [markdown]
# ### test-1

# %%
nums = [1, 2, 3, 1]
expected_output = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.ipynb/CodeChallenges/leetcode/217-contains-duplicate.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/CodeChallenges/leetcode/217-contains-duplicate.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> nums = [1, 2, 3, 1]
# ----> <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/CodeChallenges/leetcode/217-contains-duplicate.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> expected_output = true
#
# NameError: name 'true' is not defined

# %%
test_bruteForce_function(nums, target, expected_output)

# %%
test_function(nums, target, expected_output)

# %% [markdown]
# ### test-2

# %%
nums = [3, 2, 4]
target = 6
expected_output = [1, 2]

# %%
test_bruteForce_function(nums, target, expected_output)

# %%
test_function(nums, target, expected_output)

# %% [markdown]
# ### test-3

# %%
nums = [3, 3]
target = 6
expected_output = [0, 1]

# %%
test_bruteForce_function(nums, target, expected_output)

# %%
test_function(nums, target, expected_output)

# %% [markdown]
# ## Summary
#
# My Solution: URL
# <table>
#  <tr>
# <td><img src="../images/tc-Oof1.png"> </td>
# <td><img src="../images/sc-Oof1.png"> </td>
# <tr>
# </table>
