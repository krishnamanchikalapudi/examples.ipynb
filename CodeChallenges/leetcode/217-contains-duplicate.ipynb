# %% [markdown]
# # 217. Contains Duplicate
#
# Problem: https://leetcode.com/problems/contains-duplicate/
#
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
# Example 1:
# ``````
# Input: [1,2,3,1]
# Output: true
# Explanation: The element 1 occurs at the indices 0 and 3.
# ``````
#
# Example 2:
# ``````
# Input: [1,2,3,4]
# Output: false
# Explanation: All elements are distinct.
# ``````
#
# Example 3:
# ``````
# Input: [1,1,1,3,3,4,3,2,4,2]
# Output: true
#  ``````
#
# Constraints:
# - 1 <= nums.length <= 105
# - 109 <= nums[i] <= 109
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\lib\site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import List


class BruteForceSolution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        """
        :type nums: List[int]
        :rtype: boolean
        """
        for i in range(len(nums)):  # O(n)
            for j in range(i + 1, len(nums)):  # O(n)
                if nums[i] == nums[j]:  # O(1)
                    return True  # O(1)
        return False  # O(1)
# Out:
# time: 16 ms (started: 2025-09-01 14:42:06 -07:00)

# %% [markdown]
# The Brute Force solution has a `TIME complexity` of <b>O(n <sup>2</sup>)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ### BEST

# %%
class Solution:
    def containsDuplicate(self, nums: List[int]) -> bool:
        """
        :type nums: List[int]
        :rtype: boolean
        """
        hashMap = {}  # val -> index   # O(n)
        for i in range(len(nums)):  # O(n)
            num = nums[i]  # O(1)
            if num in hashMap:  # O(1)
                return True  # O(1)
            hashMap[nums[i]] = i  # O(1)

        return False  # O(1)
# Out:
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>
# - Time: each element is visited once
# - Space: storing upto n elements in hashmap

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 31 ms (started: 2025-09-01 14:42:06 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(nums, expected_output):
    s = BruteForceSolution()
    actual = s.containsDuplicate(nums)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
# Best Solution Test Case
def test_solution(nums, expected_output):
    s = Solution()
    actual = s.containsDuplicate(nums)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %% [markdown]
# ### test-1

# %%
nums = [1, 2, 3, 1]
expected_output = True
# Out:
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %% [markdown]
# ### test-2

# %%
nums = [1, 2, 3, 4]
expected_output = False
# Out:
# time: 16 ms (started: 2025-09-01 14:42:06 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %% [markdown]
# ### test-3

# %%
nums = [1, 1, 1, 3, 3, 4, 3, 2, 4, 2]
expected_output = True
# Out:
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %% [markdown]
# ### test-4

# %%
nums = [1, 2, 3, 3]
expected_output = True
# Out:
# time: 0 ns (started: 2025-09-01 14:42:06 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 0 ns (started: 2025-09-01 14:42:07 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/contains-duplicate/submissions/1735603920/
#
# <img src="./submission/217-contains-duplicate.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
