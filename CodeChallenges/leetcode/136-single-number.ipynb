# %% [markdown]
# # 136. Single Number
#
# Problem: https://leetcode.com/problems/single-number/
#
# Given a non-empty array of integers `nums`, every element appears twice except for one. Find that single one.
#
# You must implement a solution with a linear runtime complexity and use only constant extra space.
#
# Example 1:
# ``````
# Input: nums = [2,2,1]
# Output: 1
# ``````
#
# Example 2:
# ``````
# Input: [4,1,2,1,2]
# Output: 4
# ``````
#
# Example 3:
# ``````
# Input:  nums = [1]
# Output: 1
#  ``````
#
# Constraints:
# - 1 <= nums.length <= 3 * 10<sup>4</sup>
# - -3 * 10<sup>4</sup> <= nums[i] <= 3 * 10<sup>4</sup>
# - Each element in the array appears twice except for one element which appears only once.
#
# Difficulty: <b>Medium</b>
#
# Tags:
# - `Array`
# - `Bit Manipulation`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 146 μs (started: 2025-09-24 15:34:29 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:

    def singleNumber(self, nums: List[int]) -> int:
        result = 0
        for num in nums:  # O(n)
            result ^= num  # XOR each number

        return result  # O(1)
# Out:
# time: 454 μs (started: 2025-09-24 15:34:29 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(?)</b> and `SPACE complexity` of <b>O(?)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()


def test_solution(input, expected_output):
    sol = Solution()
    actual = sol.singleNumber(input)

    try:
        if isinstance(expected_output, list):
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 5.22 ms (started: 2025-09-24 15:34:29 -07:00)

# %% [markdown]
# ### test-1

# %%
 nums = [2,2,1]
expected_output = 1

test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 1 = Expected: 1
# time: 444 μs (started: 2025-09-24 15:34:29 -07:00)

# %% [markdown]
# ### test-2

# %%
nums = [4, 1, 2, 1, 2]
expected_output = 4

test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 211 μs (started: 2025-09-24 15:34:29 -07:00)

# %% [markdown]
# ### test-3

# %%
nums = [1]
expected_output = 1

test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 1 = Expected: 1
# time: 178 μs (started: 2025-09-24 15:34:29 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/single-number/submissions/1781724232/
#
#
# <img src="./submission/136-single-number.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
