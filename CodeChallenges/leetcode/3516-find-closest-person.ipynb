# %% [markdown]
# # Find Closest Person
#
# Problem: https://leetcode.com/problems/find-closest-person/
#
# You are given three integers x, y, and z, representing the positions of three people on a number line:
# - x is the position of Person 1.
# - y is the position of Person 2.
# - z is the position of Person 3, who does not move.
# Both Person 1 and Person 2 move toward Person 3 at the same speed.
#
# Determine which person reaches Person 3 first:
# - Return 1 if Person 1 arrives first.
# - Return 2 if Person 2 arrives first.
# - Return 0 if both arrive at the same time.
# - Return the result accordingly.
#
# Example 1:
# ``````
# Input: x = 2, y = 7, z = 4
# Output: 1
# Explanation:
# - Person 1 is at position 2 and can reach Person 3 (at position 4) in 2 steps.
# - Person 2 is at position 7 and can reach Person 3 in 3 steps.
# Since Person 1 reaches Person 3 first, the output is 1.
# ``````
#
# Example 2:
# ``````
# Input: x = 2, y = 5, z = 6
# Output: 2
# Explanation:
# - Person 1 is at position 2 and can reach Person 3 (at position 6) in 4 steps.
# - Person 2 is at position 5 and can reach Person 3 in 1 step.
# Since Person 2 reaches Person 3 first, the output is 2.
# ``````
#
# Example 3:
# ``````
# Input: x = 1, y = 5, z = 3
# Output: 0
# Explanation:
# - Person 1 is at position 1 and can reach Person 3 (at position 3) in 2 steps.
# - Person 2 is at position 5 and can reach Person 3 in 2 steps.
# Since both Person 1 and Person 2 reach Person 3 at the same time, the output is 0.
#  ``````
#
# Constraints:
# - 1 <= x, y, z <= 100
#
#
# - Interview Questions: https://leetcode.com/studyplan/top-interview-150/

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %pip install -q ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 186 μs (started: 2025-04-21 19:18:41 -07:00)

# %% [markdown]
# ## USE-CASE
# ### Q: Which use-case would the 'Find Closest Person' problem be used for?
# #### ????

# %% [markdown]
# ## BEST Solution

# %%
class Solution(object):
    def findClosest(self, x, y, z):
        """
        :type x: int
        :type y: int
        :type z: int
        :rtype: int
        """
        p1ReachP3inSteps = abs(x-z)
        p2ReachP3inSteps = abs(y-z)
               
        if (p1ReachP3inSteps < p2ReachP3inSteps): # Return 1 if Person 1 arrives first.
            print(f"Person 1 is at position 2 and can reach Person 3 (at position {p1ReachP3inSteps}) in 4 steps.")
            return 1
        elif (p1ReachP3inSteps > p2ReachP3inSteps): # Return 2 if Person 2 arrives first.
            print(f"Person 2 is at position {p2ReachP3inSteps} and can reach Person 3 in 1 step.")
            return 2
        else: # Return 0 if both arrive at the same time.
            return 0
# Out:
# time: 794 μs (started: 2025-04-21 19:18:41 -07:00)

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

def test_function(x,y,z, expected_output)  :
    s = Solution()
    actual = s.findClosest( x, y, z)

    try :
        assert actual == expected_output
        print(f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}")
    except AssertionError:
        print(f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}")
# Out:
# time: 6.14 ms (started: 2025-04-21 19:18:41 -07:00)

# %% [markdown]
# ### test-1

# %%
x = 2
y = 7
z = 4
expected_output = 1

test_function(x, y, z,  expected_output)
# Out:
# Person 1 is at position 2 and can reach Person 3 (at position 2) in 4 steps.
# Test PASSED; Actual: 1 = Expected: 1
# time: 431 μs (started: 2025-04-21 19:18:41 -07:00)

# %% [markdown]
# ### test-2

# %%
x = 2
y = 5
z = 6
expected_output = 2

test_function(x, y, z,  expected_output)
# Out:
# Person 2 is at position 1 and can reach Person 3 in 1 step.
# Test PASSED; Actual: 2 = Expected: 2
# time: 562 μs (started: 2025-04-21 19:18:41 -07:00)

# %% [markdown]
# ### test-3

# %%
x = 1
y = 5
z = 3
expected_output = 0

test_function(x, y, z,  expected_output)
# Out:
# Test PASSED; Actual: 0 = Expected: 0
# time: 202 μs (started: 2025-04-21 19:18:41 -07:00)

# %% [markdown]
# ## Summary
#
# My Solution: https://leetcode.com/problems/find-closest-person/solutions/6675727/find-closest-person-by-kmanchikalapudi-gvtr/
# <table>
#  <tr>
# <td><img src="../images/tc-Oof1.png"> </td>
# <td><img src="../images/sc-Oof1.png"> </td>
# <tr>
# </table>
