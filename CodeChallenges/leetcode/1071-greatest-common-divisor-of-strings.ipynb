# %% [markdown]
# # 1071. Greatest Common Divisor of Strings
#
# Problem: https://leetcode.com/problems/greatest-common-divisor-of-strings/
#
# For two strings `s` and `t`, we say "t divides s" if and only if `s = t + t + t + ... + t + t` (i.e., t is concatenated with itself one or more times).
#
# Given two strings `str1` and `str2`, return the largest string `x` such that `x` divides both `str1` and `str2`.
#
# Example 1:
# ``````
# Input: str1 = "ABCABC", str2 = "ABC"
# Output: "ABC"
# ``````
#
# Example 2:
# ``````
# Input: str1 = "ABABAB", str2 = "ABAB"
# Output: "AB"
# ``````
#
# Example 3:
# ``````
# Input: str1 = "LEET", str2 = "CODE"
# Output: ""
#  ``````
#
# Constraints:
# - 1 <= str1.length, str2.length <= 1000
# - `str1` and `str2` consist of English uppercase letters.
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `Math`
# - `String`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade --user pip
# Out:
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 154 μs (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# ## Solution

# %%
import math
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:

    def gcdOfStrings(self, str1: str, str2: str) -> str:
        s1len = len(str1)
        s2len = len(str2)
        # # Check if concatenation of str1 and str2 is the same as str2 and str1
        if str1 + str2 != str2 + str1:
            return ""

        # Calculate the GCD of the lengths of str1 and str2
        gcd_length = math.gcd(s1len, s2len)

        # Extract and return the GCD string
        return str1[:gcd_length]
# Out:
# time: 572 μs (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n+m)</b> and `SPACE complexity` of <b>O(n+m)</b>
# - n is the length of `str1`
# - m is the length of `str2`

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()


# Best Solution Test Case
def test_solution(input1, input2, expected_output):
    sol = Solution()
    actual = sol.gcdOfStrings(input1, input2)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 6.94 ms (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# ### test-1

# %%
str1 = "ABCABC"
str2 = "ABC"
expected_output = "ABC"

test_solution(str1, str2, expected_output)
# Out:
# Test PASSED; Actual: ABC = Expected: ABC
# time: 321 μs (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# ### test-2

# %%
str1 = "ABABAB"
str2 = "ABAB"
expected_output = "AB"

test_solution(str1, str2, expected_output)
# Out:
# Test PASSED; Actual: AB = Expected: AB
# time: 207 μs (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# ### test-3

# %%
str1 = "LEET"
str2 = "CODE"
expected_output = ""

test_solution(str1, str2, expected_output)
# Out:
# Test PASSED; Actual:  = Expected:
# time: 241 μs (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# ### test-4

# %%
str1 = "NANANA"
str2 = "NANA"
expected_output = "NA"

test_solution(str1, str2, expected_output)
# Out:
# Test PASSED; Actual: NA = Expected: NA
# time: 310 μs (started: 2025-10-03 07:33:36 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/greatest-common-divisor-of-strings/submissions/1790229733/
#
#
# <img src="./submission/1071-greatest-common-divisor-of-strings.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
