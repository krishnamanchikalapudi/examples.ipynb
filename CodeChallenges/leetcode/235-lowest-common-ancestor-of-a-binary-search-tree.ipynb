# %% [markdown]
# # 235. Lowest Common Ancestor of a Binary Search Tree
#
# Problem: https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-search-tree/
#
# Given a binary search tree (BST), find the lowest common ancestor (LCA) node of two given nodes in the BST.
#
# According to the [definition of LCA on Wikipedia](https://en.wikipedia.org/wiki/Lowest_common_ancestor): “The lowest common ancestor is defined between two nodes `p` and `q` as the lowest node in `T` that has both `p` and `q` as descendants (where we allow a node to be a descendant of itself).”
#
# Example 1:
# <br /><img src="./images/235-lowest-common-ancestor-of-a-binary-search-tree-1.png" /> <br/>
# ``````
# Input: root = [6,2,8,0,4,7,9,null,null,3,5], p = 2, q = 8
# Output: 6
# Explanation: The LCA of nodes 2 and 8 is 6.
# ``````
#
# Example 2:
# <br /><img src="./images/235-lowest-common-ancestor-of-a-binary-search-tree-2.png" /> <br/>
# ``````
# Input: root = [6,2,8,0,4,7,9,null,null,3,5], p = 2, q = 4
# Output: 2
# Explanation: The LCA of nodes 2 and 4 is 2, since a node can be a descendant of itself according to the LCA definition.
# ``````
#
# Example 3:
# ``````
# Input: root = [2,1], p = 2, q = 1
# Output: 2
#  ``````
#
# Constraints:
# - The number of nodes in the tree is in the range [2, 10<sup>5</sup>].
# - -10<sup>9</sup> <= Node.val <= 10<sup>9</sup>
# - All Node.val are unique.
# - p != q
# - p and q will exist in the BST.
#
# Difficulty: <b>Medium</b>
#
# Tags:
# - `Tree`
# - `Depth-First Search`
# - `Binary Search Tree`
# - `Binary Tree`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.14/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 96.7 μs (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def lowestCommonAncestor(self, root: TreeNode, p: TreeNode, q: TreeNode) -> TreeNode:
        while root:     # O(h) time
            if p.val < root.val and q.val < root.val:
                root = root.left
            elif p.val > root.val and q.val > root.val:
                root = root.right
            else:
                return root # O(1)
# Out:
# time: 578 μs (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(h)</b> and `SPACE complexity` of <b>O(1)</b>
# - h is the height of the tree

# %% [markdown]
# ## Test cases

# %% [markdown]
# ### Functions: Tree

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
    ) 

def get_tree_node(val):
    """Return a new TreeNode with the given value."""
    return TreeNode(val)

def create_tree(values: List[Optional[int]]):
    if not values:
        return None
    root = TreeNode(values[0])
    queue = [root]
    i = 1
    while queue and i < len(values):
        node = queue.pop(0)
        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1
    return root

def tree_to_list(root):
    if not root:
        return []
    result = []
    queue = [root]
    while queue:
        node = queue.pop(0)
        if node:
            result.append(node.val)
            queue.extend([node.left, node.right])
    return result
# Out:
# time: 564 μs (started: 2025-10-20 21:38:11 -07:00)

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# Best Solution Test Case
def test_solution(input1, input2, input3, expected_output):
    sol = Solution()
    actual = sol.lowestCommonAncestor(input1, input2, input3)
    # If expected_output is int, compare actual.val
    if isinstance(expected_output, int):
        passed = (actual is not None and actual.val == expected_output)
        actual_val = actual.val if actual is not None else None
    else:
        passed = (actual == expected_output)
        actual_val = actual
    try:
        assert passed
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual_val} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual_val} != Expected: {expected_output}"
        )
# Out:
# time: 6.82 ms (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# ### test-1

# %%
root = [6,2,8,0,4,7,9,None,None,3,5]
p = 2
q = 8
expected_output = 6

test_solution(create_tree(root), get_tree_node(p), get_tree_node(q), expected_output)
# Out:
# Test PASSED; Actual: 6 = Expected: 6
# time: 387 μs (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# ### test-2

# %%
root = [6,2,8,0,4,7,9,None,None,3,5]
p = 2
q = 4
expected_output = 2

test_solution(create_tree(root), get_tree_node(p), get_tree_node(q), expected_output)
# Out:
# Test PASSED; Actual: 2 = Expected: 2
# time: 378 μs (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# ### test-3

# %%
root = [5,3,8,1,4,7,9,None,2]
p = 3
q = 8
expected_output = 5


test_solution(create_tree(root), get_tree_node(p), get_tree_node(q), expected_output)
# Out:
# Test PASSED; Actual: 5 = Expected: 5
# time: 602 μs (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# ### test-4

# %%
root = [5,3,8,1,4,7,9,None,2]
p = 3 
q = 4
expected_output = 3


test_solution(create_tree(root), get_tree_node(p), get_tree_node(q), expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 1.07 ms (started: 2025-10-20 21:38:11 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-search-tree/submissions/1807233928/
#
#
# <img src="./submission/235-lowest-common-ancestor-of-a-binary-search-tree.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
