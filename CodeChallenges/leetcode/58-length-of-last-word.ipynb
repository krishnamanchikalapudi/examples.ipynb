# %% [markdown]
# # 58. Length of Last Word
#
# Problem: https://leetcode.com/problems/length-of-last-word/
#
# Given a string `s` consisting of words and spaces, return the length of the last word in the string.
#
# A word is a maximal substring consisting of non-space characters only.
#
#
# Example 1:
# ``````
# Input: s = "Hello World"
# Output: 5
# Explanation: The last word is "World" with length 5.
# ``````
#
# Example 2:
# ``````
# Input: s = "   fly me   to   the moon  "
# Output: 4
# Explanation: The last word is "moon" with length 4.
# ``````
#
# Example 3:
# ``````
# Input: s = "luffy is still joyboy"
# Output: 6
# Explanation: The last word is "joyboy" with length 6.
#  ``````
#
# Constraints:
# - `1 <= s.length <= 104`
# - `s` consists of only English letters and spaces ' '.
# - There will be at least one word in `s`.
#
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")
# Out:
# time: 466 μs (started: 2025-08-21 20:44:58 -07:00)

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.13/site-packages (25.2)
# time: 985 ms (started: 2025-08-21 20:44:58 -07:00)

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 973 ms (started: 2025-08-21 20:44:59 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
class BruteForceSolution:

    def lengthOfLastWord(self, s: str) -> int:

        length = 0  # O(1)
        in_word = False  # O(1)

        for char in s[::-1]:  # O(n)
            if char != " ":  # O(1)
                length += 1  # O(1)
                in_word = True  # O(1)
            elif in_word:  # O(1)
                break  # O(1)

        return length  # O(1)
# Out:
# time: 577 μs (started: 2025-08-21 20:45:00 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(1)

# %% [markdown]
# ### BEST

# %%
class Solution:

    def lengthOfLastWord(self, s: str) -> int:
        words = s.split()  # O(n)
        if words:  # Check if the list is not empty
            words_length = len(words)  # O(1)
            last_word = words[words_length - 1]  # O(1)
            return len(last_word)  # O(1)

        return 0  # O(1)
# Out:
# time: 564 μs (started: 2025-08-21 20:45:00 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(1)

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 194 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(nums, expected_output):
    s = BruteForceSolution()
    actual = s.lengthOfLastWord(nums)

    try:
        if isinstance(nums, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 356 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
# Best Solution Test Case
def test_solution(input, expected_output):
    s = Solution()
    actual = s.lengthOfLastWord(input)

    try:
        if isinstance(input, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 321 μs (started: 2025-08-21 20:45:00 -07:00)

# %% [markdown]
# ### test-1

# %%
s = "Hello World"
expected_output = 5
# Out:
# time: 334 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
test_bruteForce(s, expected_output)
# Out:
# Test PASSED; Actual: 5 = Expected: 5
# time: 137 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: 5 = Expected: 5
# time: 209 μs (started: 2025-08-21 20:45:00 -07:00)

# %% [markdown]
# ### test-2

# %%
s = "   fly me   to   the moon  "
expected_output = 4
# Out:
# time: 122 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
test_bruteForce(s, expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 165 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 145 μs (started: 2025-08-21 20:45:00 -07:00)

# %% [markdown]
# ### test-3

# %%
s = "luffy is still joyboy"
expected_output = 6
# Out:
# time: 624 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
test_bruteForce(s, expected_output)
# Out:
# Test PASSED; Actual: 6 = Expected: 6
# time: 187 μs (started: 2025-08-21 20:45:00 -07:00)

# %%
test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: 6 = Expected: 6
# time: 145 μs (started: 2025-08-21 20:45:00 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/length-of-last-word/submissions/1743840817/
#
# <img src="./submission/58-length-of-last-word.png" />
# <br />
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
