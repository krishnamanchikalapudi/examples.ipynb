# %% [markdown]
# # Remove Element
#
# Problem: https://leetcode.com/problems/remove-element/
#
# Given an integer array nums and an integer val, remove all occurrences of val in nums in-place. The order of the elements may be changed. Then return the number of elements in nums which are not equal to val.
#
# Consider the number of elements in nums which are not equal to val be k, to get accepted, you need to do the following things:
# - Change the array nums such that the first k elements of nums contain the elements which are not equal to val. The remaining elements of nums are not important as well as the size of nums.
# - Return k.
#
# ### Custom Judge:
#
# The judge will test your solution with the following code:
# `````
# int[] nums = [...]; // Input array
# int val = ...; // Value to remove
# int[] expectedNums = [...]; // The expected answer with correct length.
#                             // It is sorted with no values equaling val.
#
# int k = removeElement(nums, val); // Calls your implementation
#
# assert k == expectedNums.length;
# sort(nums, 0, k); // Sort the first k elements of nums
# for (int i = 0; i < actualLength; i++) {
#     assert nums[i] == expectedNums[i];
# }
# `````
# If all assertions pass, then your solution will be accepted.
#
#
#
# Example 1:
# ``````
# Input: nums = [3,2,2,3], val = 3
# Output: 2, nums = [2,2,_,_]
# Explanation: Your function should return k = 2, with the first two elements of nums being 2.
# It does not matter what you leave beyond the returned k (hence they are underscores).
# ``````
#
# Example 2:
# ``````
# Input: nums = [0,1,2,2,3,0,4,2], val = 2
# Output: 5, nums = [0,1,4,0,3,_,_,_]
# Explanation: Your function should return k = 5, with the first five elements of nums containing 0, 0, 1, 3, and 4.
# Note that the five elements can be returned in any order.
# It does not matter what you leave beyond the returned k (hence they are underscores).
# ``````
#
#
# Constraints:
# - 0 <= nums.length <= 100
# - 0 <= nums[i] <= 50
# - 0 <= val <= 100
#
#
#
# - Interview Questions: https://leetcode.com/studyplan/top-interview-150/

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime

# %% [markdown]
# ## USE-CASE
# ### Q: Which use-case would the 'Remove Element' problem be used for?
# #### ????

# %% [markdown]
# ## BEST Solution

# %%
class Solution(object):
    def removeElement(self, nums, val):
        """
        :type nums: List[int]
        :type val: int
        :rtype: int
        """
        rtype = 0
        for i in range(len(nums)):
            # print(f"nums[i]: {nums[i]}   val: {val}")
            if (val != nums[i]):
                # print(f"nums[i]: {nums[i]} !=  val: {val}")
                nums[rtype] = nums[i]
                rtype += 1
            
            print(rtype)
        print (f"nums: {nums}")
        return rtype

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored


tc = unittest.TestCase()

def test_function(nums, val, expected_output)  :
    s = Solution()
    actual = s.removeElement(nums, val)

    try :
        assert (actual == expected_output)
        print(f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}")
    except AssertionError:
        print(f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output} and/or Actual: {s.removeElement.nums} != Expected: {expected_nums}")

# %% [markdown]
# ### test-1

# %%
nums = [3,2,2,3]
val = 3
expected_output = 2
expected_nums= [2,2]

test_function(nums, val, expected_output)

# %% [markdown]
# ### test-2

# %%
nums = [0,1,2,2,3,0,4,2]
target = 2
expected_output = 5

test_function(nums, val, expected_output)

# %% [markdown]
# ## Summary
#
# My Solution: https://leetcode.com/problems/remove-element/solutions/6675722/remove-element-by-kmanchikalapudi-rwqn/
# <table>
#  <tr>
# <td><img src="../images/tc-OofN.png"> </td>
# <td><img src="../images/sc-Oof1.png"> </td>
# <tr>
# </table>
