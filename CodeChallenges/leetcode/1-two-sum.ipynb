# %% [markdown]
# # Two Sum
#
# Problem: https://leetcode.com/problems/two-sum
#
#
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
# Example 1:
# ``````
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# ``````
#
# Example 2:
# ``````
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# ``````
#
# Example 3:
# ``````
# Input: nums = [3,3], target = 6
# Output: [0,1]
#  ``````
#
# Constraints:
# - 2 <= nums.length <= 104
# - -109 <= nums[i] <= 109
# - -109 <= target <= 109
# - Only one valid answer exists.
#
#
# Follow-up: Can you come up with an algorithm that is less than O(n2) time complexity?
#
# - Interview Questions: https://leetcode.com/studyplan/top-interview-150/

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %pip install -q ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# time: 181 μs (started: 2025-08-11 16:50:34 -07:00)

# %% [markdown]
# ## USE-CASE
# ### Q: Which use-case would the 'Two Sum' problem be used for?
# #### ????

# %% [markdown]
# ## BEST Solution

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        hashmap = {} # O(n)
        # Iterate through the list of numbers
        for i in range(len(nums)): # O(n)
            diff = (target - nums[i]) # O(1)

            if (diff in hashmap): # O(1)
                return [hashmap[diff], i]  # O(1)
                
            hashmap[nums[i]] = i # O(1)
        return None # O(1)
# Out:
# time: 438 μs (started: 2025-08-11 16:50:34 -07:00)

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

def test_twoSum(nums, target, expected_output)  :
    s = Solution()
    actual = s.twoSum(nums, target)

    try :
        assert actual == expected_output
        print(f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}")
    except AssertionError:
        print(f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}")
# Out:
# time: 10.4 ms (started: 2025-08-11 16:50:34 -07:00)

# %% [markdown]
# ### test-1

# %%
nums = [2,7,11,15]
target = 9
expected_output = [0,1]

test_twoSum(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [0, 1] = Expected: [0, 1]
# time: 422 μs (started: 2025-08-11 16:50:34 -07:00)

# %% [markdown]
# ### test-2

# %%
nums = [3,2,4]
target = 6
expected_output =[1,2]

test_twoSum(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [1, 2] = Expected: [1, 2]
# time: 478 μs (started: 2025-08-11 16:50:34 -07:00)

# %% [markdown]
# ### test-3

# %%
nums = [3,3]
target = 6
expected_output =[0,1]

test_twoSum(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [0, 1] = Expected: [0, 1]
# time: 214 μs (started: 2025-08-11 16:50:34 -07:00)

# %% [markdown]
# ## Summary
#
# My Solution: https://leetcode.com/problems/two-sum/solutions/6675747/two-sum-by-kmanchikalapudi-2fad/
# <table>
#  <tr>
# <td><img src="../images/tc-OofN.png"> </td>
# <td><img src="../images/sc-OofN.png"> </td>
# <tr>
# </table>
