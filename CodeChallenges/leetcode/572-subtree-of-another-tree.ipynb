# %% [markdown]
# # 572. Subtree of Another Tree
#
# Problem: https://leetcode.com/problems/subtree-of-another-tree/
#
# Given the roots of two binary trees `root` and `subRoot`, return `true` if there is a subtree of `root` with the same structure and node values of `subRoot` and `false` otherwise.
#
# A subtree of a binary tree tree is a `tree` that consists of a node in `tree` and all of this node's descendants. The tree `tree` could also be considered as a subtree of itself.
#
# Example 1:
# <br/><img src="./images/572-subtree-of-another-tree-1.jpg" /><br/>
# ``````
# Input: root = [3,4,5,1,2], subRoot = [4,1,2]
# Output: true
# ``````
#
# Example 2:
# <br/><img src="./images/572-subtree-of-another-tree-1.jpg" /><br/>
# ``````
# Input: root = [3,4,5,1,2,null,null,null,null,0], subRoot = [4,1,2]
# Output: false
# ``````
#
# Constraints:
# - The number of nodes in the root tree is in the range [1, 2000].
# - The number of nodes in the subRoot tree is in the range [1, 1000].
# - -10<sup>4</sup> <= root.val <= 10<sup>4</sup>
# - -10<sup>4</sup> <= subRoot.val <= 10<sup>4</sup>
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `Tree`
# - `Depth-First Search`
# - `String Matching`
# - `Binary Tree`
# - `Hash Function`
#
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")
# Out:
# time: 178 μs (started: 2025-10-18 21:27:30 -07:00)

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.14/site-packages (25.2)
# time: 890 ms (started: 2025-10-18 21:27:30 -07:00)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.01 s (started: 2025-10-18 21:27:31 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


# Definition for a binary tree node.
class TreeNode:
     def __init__(self, val=0, left=None, right=None):
         self.val = val
         self.left = left
         self.right = right

class Solution:
    def isSubtree(self, root: Optional[TreeNode], subRoot: Optional[TreeNode]) -> bool:
        if subRoot is None:
            return True
        
        if root is None and subRoot!= None:
            return False
        
        # check if the current tree is the same as subRoot
        if self.isSameTree(root, subRoot):
            return True
        
        left_check = self.isSubtree(root.left, subRoot)
        right_check = self.isSubtree(root.right, subRoot)

        return left_check or right_check

    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        # both trees are None
        if p is None and q is None:
            return True
        
        # Tree are not identical if one is None or values are different
        if p is None or q is None or p.val != q.val:
            return False

        # Recursively compare left and right subtrees
        left_comparison = self.isSameTree(p.left, q.left)
        right_comparison = self.isSameTree(p.right, q.right)

        # Both left and right subtrees must be identical
        return left_comparison and right_comparison
# Out:
# time: 604 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(h)</b>
# - h is the height of the tree

# %% [markdown]
# ## Test cases

# %% [markdown]
# ### Functions: Tree

# %%
def create_tree(values):
    if not values:
        return None
    root = TreeNode(values[0])
    queue = [root]
    i = 1
    while queue and i < len(values):
        node = queue.pop(0)
        if i < len(values) and values[i] is not None:
            node.left = TreeNode(values[i])
            queue.append(node.left)
        i += 1
        if i < len(values) and values[i] is not None:
            node.right = TreeNode(values[i])
            queue.append(node.right)
        i += 1
    return root


def tree_to_list(root):
    if not root:
        return []
    result = []
    queue = [root]
    while queue:
        node = queue.pop(0)
        if node:
            result.append(node.val)
            queue.extend([node.left, node.right])
    return result
# Out:
# time: 504 μs (started: 2025-10-18 21:27:32 -07:00)

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# Best Solution Test Case
def test_solution(input1, input2, expected_output):
    sol = Solution()
    actual = sol.isSubtree(input1, input2)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 658 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ### test-1

# %%
root = [3,4,5,1,2]
subRoot = [4,1,2]
expected_output = True

test_solution(create_tree(root), create_tree(subRoot), expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 337 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ### test-2

# %%
root = [3,4,5,1,2,None,None,None,None,0]
subRoot = [4,1,2]
expected_output = False

test_solution(create_tree(root), create_tree(subRoot), expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 268 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ### test-3

# %%
root = [1,2,3,4,5]
subRoot = [2,4,5]
expected_output = True

test_solution(create_tree(root), create_tree(subRoot), expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 217 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ### test-4

# %%
root = [1,2,3,4,5,None,None,6]
subRoot = [2,4,5]
expected_output = False

test_solution(create_tree(root), create_tree(subRoot), expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 324 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ### test-5

# %%
root = [None]
subRoot = [4,1,2]
expected_output = False


test_solution(create_tree(root), create_tree(subRoot), expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 228 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ### test-6

# %%
root = [None, None, None]
subRoot = [1,2,3]
expected_output = False


test_solution(create_tree(root), create_tree(subRoot), expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 207 μs (started: 2025-10-18 21:27:32 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/subtree-of-another-tree/submissions/1805599707/
#
#
# <img src="./submission/572-subtree-of-another-tree.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
