# %% [markdown]
# # 543. Diameter of Binary Tree
#
# Problem: https://leetcode.com/problems/diameter-of-binary-tree/
#
# Given the `root` of a binary tree, return the length of the diameter of the tree.
#
# The diameter of a binary tree is the length of the longest path between any two nodes in a tree. This path may or may not pass through the `root`.
#
# The length of a path between two nodes is represented by the number of edges between them.
#
#
# Example 1:
# <br/><img src="./images/543-diameter-of-binary-tree-1.jpg" /><br/>
# ``````
# Input: root = [1,2,3,4,5]
# Output: 3
# Explanation: 3 is the length of the path [4,2,1,3] or [5,2,1,3].
# ``````
#
# Example 2:
# ``````
# Input: root = [1,2]
# Output: 1
# ``````
#
# Constraints:
# - The number of nodes in the tree is in the range [1, 10<sup>4</sup>].
# - -100 <= Node.val <= 100
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `Tree`
# - `Depth-First Search`
# - `Binary Tree`
#
# ### Companies:
# - Walmart
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.14/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 181 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


# Definition for a binary tree node.
class TreeNode:
     def __init__(self, val=0, left=None, right=None):
         self.val = val
         self.left = left
         self.right = right

class Solution:
    def diameterOfBinaryTree(self, root: Optional[TreeNode]) -> int:
        self.diameter = 0
        
        def depth(node) -> int:
            if not node:
                return 0

            left_depth = depth(node.left)
            right_depth = depth(node.right)
            
            # Update the diameter if the path through the current node is larger
            self.diameter = max(self.diameter, left_depth + right_depth)
            
            # Return the depth of the tree rooted at the current node
            return 1 + max(left_depth, right_depth)

        depth(root)
        return self.diameter
# Out:
# time: 731 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(?)</b> and `SPACE complexity` of <b>O(?)</b>

# %% [markdown]
# ## Test cases

# %% [markdown]
# ### Functions: Tree

# %%
from typing import (
    Dict,
    List,
    Set,
    Tuple,
) 

def create_tree(values):
    """Create a binary tree from the given input."""
    # Accepts: None -> None, TreeNode -> returned as-is, scalar (int/str) -> single node,
    # or a list representing level-order traversal with `None` for missing nodes.
    if values is None:
        return None
    # If already a TreeNode, return it
    if isinstance(values, TreeNode):
        return values
    # If scalar (int/float/str), create a single node
    if not isinstance(values, list):
        return TreeNode(values)

    # List input: build tree in level order, None indicates missing child
    if len(values) == 0:
        return None
    root = TreeNode(values[0])
    queue = [root]
    i = 1
    while queue and i < len(values):
        node = queue.pop(0)
        # left child
        if i < len(values):
            val = values[i]
            if val is not None:
                node.left = TreeNode(val)
                queue.append(node.left)
            i += 1
        # right child
        if i < len(values):
            val = values[i]
            if val is not None:
                node.right = TreeNode(val)
                queue.append(node.right)
            i += 1
    return root


def tree_to_list(root):
    """Convert a binary tree to a level-order list representation (trim trailing Nones)."""
    if not root:
        return []
    result = []
    queue = [root]
    while queue:
        node = queue.pop(0)
        if node is None:
            result.append(None)
            continue
        result.append(node.val)
        queue.append(node.left)
        queue.append(node.right)
    # remove trailing Nones
    while result and result[-1] is None:
        result.pop()
    return result
# Out:
# time: 808 μs (started: 2025-10-23 18:57:06 -07:00)

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# Best Solution Test Case
def test_solution(input, expected_output):
    sol = Solution()
    actual = sol.diameterOfBinaryTree(input)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 4.58 ms (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-1

# %%
root = [1,2,3,4,5]
expected_output = 3

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 196 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-2

# %%
root = [1,2]
expected_output = 1

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 1 = Expected: 1
# time: 4.05 ms (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-3

# %%
root = [1,None,2,3,4,5]
expected_output = 3

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 776 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-4

# %%
root = [1,2,3]
expected_output = 2

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 2 = Expected: 2
# time: 181 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-5

# %%
root=[12,7,1,9,10,15]
expected_output=4

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 211 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-6

# %%
root=[3,9,20,15,7]
expected_output=3

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 611 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ### test-7

# %%
root=[9,7,None,None,1,8,10,None,12]
expected_output=4

test_solution(create_tree(root), expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 332 μs (started: 2025-10-23 18:57:06 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/diameter-of-binary-tree/submissions/1809926520/
#
#
# <img src="./submission/543-diameter-of-binary-tree.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
