# %% [markdown]
# # 88. Merge Sorted Array
#
# Problem: https://leetcode.com/problems/merge-sorted-array/
#
# You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n, representing the number of elements in nums1 and nums2 respectively.
#
# Merge nums1 and nums2 into a single array sorted in non-decreasing order.
#
# The final sorted array should not be returned by the function, but instead be stored inside the array _nums1_. To accommodate this, _nums1_ has a length of _m + n_, where the first _m_ elements denote the elements that should be merged, and the last _n_ elements are set to 0 and should be ignored. _nums2_ has a length of _n_.
#
#
#
# Example 1:
# ``````
# Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
# Output: [1,2,2,3,5,6]
# Explanation: The arrays we are merging are [1,2,3] and [2,5,6].
# The result of the merge is [1,2,2,3,5,6] with the underlined elements coming from nums1.
# ``````
#
# Example 2:
# ``````
# Input: nums1 = [1], m = 1, nums2 = [], n = 0
# Output: [1]
# Explanation: The arrays we are merging are [1] and [].
# The result of the merge is [1].
# ``````
#
# Example 3:
# ``````
# Input: nums1 = [0], m = 0, nums2 = [1], n = 1
# Output: [1]
# Explanation: The arrays we are merging are [] and [1].
# The result of the merge is [1].
# Note that because m = 0, there are no elements in nums1. The 0 is only there to ensure the merge result can fit in nums1.
#  ``````
#
# Constraints:
# - nums1.length == m + n
# - nums2.length == n
# - 0 <= m, n <= 200
# - 1 <= m + n <= 200
# - -109 <= nums1[i], nums2[j] <= 109
#
# Follow up: Can you come up with an algorithm that runs in O(m + n) time?
#
#
# - Interview Questions: https://leetcode.com/studyplan/top-interview-150/

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# time: 135 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import List


class BruteForceSolution:

    def merge(self, nums1, m, nums2, n):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        merged = nums1[:m] + nums2  # combine elements from nums1 and nums2

        # Step 2: Sort the combined list
        merged.sort()

        # Step 3: Overwrite nums1 with merged
        for i in range(m + n):
            nums1[i] = merged[i]
# Out:
# time: 470 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# The Brute Force solution has a `TIME complexity` of <b>O(n <sup>2</sup>)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ### BEST

# %%
class Solution(object):
    def merge(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        for i in range(n):  # O(n)
            nums1[m + i] = nums2[i]  # O(1)

        nums1.sort()  # O(n log n)

        return nums1
# Out:
# time: 375 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# The Brute Force solution has a `TIME complexity` of <b>O(n log n)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 7.62 ms (started: 2025-08-15 09:25:54 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(nums1, m, nums2, n, expected_output):
    s = BruteForceSolution()
    actual = s.merge(nums1, m, nums2, n)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 379 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
# Best Solution Test Case
def test_solution(nums1, m, nums2, n, expected_output):
    s = Solution()
    actual = s.merge(nums1, m, nums2, n)
    print(f"actual: {actual}  expected: {expected_output}")

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 570 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# ### test-1

# %%
nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3
expected_output = [1, 2, 2, 3, 5, 6]
# Out:
# time: 291 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
test_bruteForce(nums1, m, nums2, n, expected_output)
# Out:
# Test FAILED; Actual: None != Expected: [1, 2, 2, 3, 5, 6]
# time: 352 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
test_solution(nums1, m, nums2, n, expected_output)
# Out:
# actual: [1, 2, 2, 2, 5, 6]  expected: [1, 2, 2, 3, 5, 6]
# Test FAILED; Actual: [1, 2, 2, 2, 5, 6] != Expected: [1, 2, 2, 3, 5, 6]
# time: 196 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# ### test-2

# %%
nums1 = [1]
m = 1
nums2 = []
n = 0
expected_output = [1]
# Out:
# time: 435 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
test_bruteForce(nums1, m, nums2, n, expected_output)
# Out:
# Test FAILED; Actual: None != Expected: [1]
# time: 175 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
test_solution(nums1, m, nums2, n, expected_output)
# Out:
# actual: [1]  expected: [1]
# Test PASSED; Actual: [1] = Expected: [1]
# time: 156 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# ### test-3

# %%
nums1 = [0]
m = 0
nums2 = [1]
n = 1
expected_output = [1]
# Out:
# time: 464 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
test_bruteForce(nums1, m, nums2, n, expected_output)
# Out:
# Test FAILED; Actual: None != Expected: [1]
# time: 137 μs (started: 2025-08-15 09:25:54 -07:00)

# %%
test_solution(nums1, m, nums2, n, expected_output)
# Out:
# actual: [1]  expected: [1]
# Test PASSED; Actual: [1] = Expected: [1]
# time: 227 μs (started: 2025-08-15 09:25:54 -07:00)

# %% [markdown]
# ## Summary
#
# My Solution: https://leetcode.com/problems/merge-sorted-array/solutions/6675733/merge-sorted-array/
# <table>
#  <tr>
# <td><img src="../images/tc-OofMn.png"> </td>
# <td><img src="../images/sc-Oof1.png"> </td>
# <tr>
# </table>
