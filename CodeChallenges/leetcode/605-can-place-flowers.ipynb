# %% [markdown]
# # 605. Can Place Flowers
#
# Problem: https://leetcode.com/problems/can-place-flowers
#
# You have a long flowerbed in which some of the plots are planted, and some are not. However, flowers cannot be planted in adjacent plots.
#
# Given an integer array `flowerbed` containing 0's and 1's, where `0` means empty and `1` means not empty, and an integer `n`, return `true` if `n` new flowers can be planted in the `flowerbed` without violating the no-adjacent-flowers rule and `false` otherwise.
#
# Example 1:
# ``````
# Input: flowerbed = [1,0,0,0,1], n = 1
# Output: true
# ``````
#
# Example 2:
# ``````
# Input: flowerbed = [1,0,0,0,1], n = 2
# Output: false
#  ``````
#
# Constraints:
# - 1 <= flowerbed.length <= 2 * 10<sup>4</sup>
# - flowerbed[i] is 0 or 1.
# - There are no two adjacent flowers in flowerbed.
# - 0 <= n <= flowerbed.length
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `Array`
# - `Greedy`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 176 μs (started: 2025-10-06 17:10:46 -07:00)

# %% [markdown]
# ## Solution

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:

    def canPlaceFlowers(self, flowerbed: List[int], n: int) -> bool:
        count = 0
        length = len(flowerbed)
        for i in range(length):  # O(n)
            if flowerbed[i] == 0:
                empty_left = (i == 0) or (flowerbed[i - 1] == 0)
                empty_right = (i == length - 1) or (flowerbed[i + 1] == 0)
                if empty_left and empty_right:
                    flowerbed[i] = 1
                    count += 1
        return count >= n
# Out:
# time: 680 μs (started: 2025-10-06 17:10:46 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()


# Best Solution Test Case
def test_solution(input, target, expected_output):
    sol = Solution()
    actual = sol.canPlaceFlowers(input, target)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 11.8 ms (started: 2025-10-06 17:10:46 -07:00)

# %% [markdown]
# ### test-1

# %%
flowerbed = [1, 0, 0, 0, 1]
n = 1
expected_output = True

test_solution(flowerbed, n, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 6.99 ms (started: 2025-10-06 17:10:46 -07:00)

# %% [markdown]
# ### test-2

# %%
flowerbed = [1, 0, 0, 0, 1]
n = 2
expected_output = False

test_solution(flowerbed, n, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 3.43 ms (started: 2025-10-06 17:10:46 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/can-place-flowers/submissions/1793651293/
#
#
# <img src="./submission/605-can-place-flowers.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
