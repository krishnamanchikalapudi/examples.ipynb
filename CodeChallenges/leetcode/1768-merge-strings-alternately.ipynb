# %% [markdown]
# # 1768. Merge Strings Alternately
#
# Problem: https://leetcode.com/problems/merge-strings-alternately/
#
# You are given two strings `word1` and `word2`. Merge the strings by adding letters in alternating order, starting with `word1`. If a string is longer than the other, append the additional letters onto the end of the merged string.
#
# Return the merged string.
#
# Example 1:
# ``````
# Input: word1 = "abc", word2 = "pqr"
# Output: "apbqcr"
# Explanation: The merged string will be merged as so:
# word1:  a   b   c
# word2:    p   q   r
# merged: a p b q c r
# ``````
#
# Example 2:
# ``````
# Input: word1 = "ab", word2 = "pqrs"
# Output: "apbqrs"
# Explanation: Notice that as word2 is longer, "rs" is appended to the end.
# word1:  a   b
# word2:    p   q   r   s
# merged: a p b q   r   s
# ``````
#
# Example 3:
# ``````
# Input: word1 = "abcd", word2 = "pq"
# Output: "apbqcd"
# Explanation: Notice that as word1 is longer, "cd" is appended to the end.
# word1:  a   b   c   d
# word2:    p   q
# merged: a p b q c   d
#  ``````
#
# Constraints:
# - 1 <= word1.length, word2.length <= 100
# - `word1` and `word2` consist of lowercase English letters.
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `Two Pointers`
# - `String`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 135 μs (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:

    def mergeAlternately(self, word1: str, word2: str) -> str:
        w1len = len(word1)
        w2len = len(word2)
        minlen = min(w1len, w2len)
        result = []

        for i in range(minlen):  # O(min(n, m))
            result.append(word1[i])
            result.append(word2[i])

        if w1len > w2len:
            result.append(word1[minlen:])
        elif w2len > w1len:
            result.append(word2[minlen:])

        return "".join(result)  # O(n)
# Out:
# time: 859 μs (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(m+n)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()


# Best Solution Test Case
def test_solution(word1, word2, expected_output):
    sol = Solution()
    actual = sol.mergeAlternately(word1, word2)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 7.43 ms (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# ### test-1

# %%
word1 = "abc"
word2 = "pqr"
expected_output = "apbqcr"

test_solution(word1, word2, expected_output)
# Out:
# Test PASSED; Actual: apbqcr = Expected: apbqcr
# time: 247 μs (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# ### test-2

# %%
word1 = "ab"
word2 = "pqrs"
expected_output = "apbqrs"

test_solution(word1, word2, expected_output)
# Out:
# Test PASSED; Actual: apbqrs = Expected: apbqrs
# time: 421 μs (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# ### test-3

# %%
word1 = "abcd"
word2 = "pq"
expected_output = "apbqcd"

test_solution(word1, word2, expected_output)
# Out:
# Test PASSED; Actual: apbqcd = Expected: apbqcd
# time: 189 μs (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# ### test-4

# %%
word1 = "abc"
word2 = "xyz"
expected_output = "axbycz"

test_solution(word1, word2, expected_output)
# Out:
# Test PASSED; Actual: axbycz = Expected: axbycz
# time: 657 μs (started: 2025-10-03 06:54:15 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/merge-strings-alternately/submissions/1790200620/
#
#
# <img src="./submission/1768-merge-strings-alternately.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
