# %% [markdown]
# # 56. Merge Intervals
#
# Problem: https://leetcode.com/problems/merge-intervals/
#
# Given an array of `intervals` where <b><i>intervals[i] = [start<sub>i</sub>, end<sub>i</sub>]</i></b>, merge all overlapping intervals, and return an array of the non-overlapping intervals that cover all the intervals in the input.
#
# Example 1:
# ``````
# Input: intervals = [[1,3],[2,6],[8,10],[15,18]]
# Output: [[1,6],[8,10],[15,18]]
# Explanation: Since intervals [1,3] and [2,6] overlap, merge them into [1,6].
# ``````
#
# Example 2:
# ``````
# Input: intervals = [[1,4],[4,5]]
# Output: [[1,5]]
# Explanation: Intervals [1,4] and [4,5] are considered overlapping.
# ``````
#
# Example 3:
# ``````
# Input:intervals = [[4,7],[1,4]]
# Output: [[1,7]]
# Explanation: Intervals [1,4] and [4,7] are considered overlapping.
#
#  ``````
#
# Constraints:
# - 1 <= intervals.length <= 10<sup>4</sup>
# - intervals[i].length == 2
# - 0 <= starti <= endi <= 10<sup>4</sup>
#
# Difficulty: <b>Medium</b>
#
# Tags:
# - `Array`
# - `Sorting`
#
# ### Companies:
# - Walmart
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.14/lib/python/site-packages (25.3)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 121 μs (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)
from unittest import result  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:
    def merge(self, intervals: List[List[int]]) -> List[List[int]]:
        if not intervals:
            return []
        
        # sort intervals based on the start time
        intervals.sort()  # O(n log n)

        # intialize with the first interval
        result = [intervals[0] ]  # O(1)
        
        # iterate through all the intervals
        for i in range (1, len(intervals)):  # O(n)
            if intervals[i][0] <= result[-1][1]:  # O(1)
                # overlapping intervals, merge them
                result[-1][1] = max(result[-1][1], intervals[i][1])  # O(1)
            else:
                # non-overlapping interval, add the current interval to result
                result.append(intervals[i])  # O(1)

        return result  # O(1)
# Out:
# time: 6.01 ms (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n log n)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# Best Solution Test Case
def test_solution(input, expected_output):
    sol = Solution()
    actual = sol.merge(input)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 2.25 ms (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-1

# %%
intervals = [[1,3],[2,6],[8,10],[15,18]]
expected_output = [[1,6],[8,10],[15,18]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[1, 6], [8, 10], [15, 18]] = Expected: [[1, 6], [8, 10], [15, 18]]
# time: 252 μs (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-2

# %%
intervals = [[1,4],[4,5]]
expected_output = [[1, 5]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[1, 5]] = Expected: [[1, 5]]
# time: 1.28 ms (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-3

# %%
intervals = [[4,7],[1,4]]
expected_output = [[1, 7]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[1, 7]] = Expected: [[1, 7]]
# time: 1.45 ms (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-4

# %%
intervals = [[1,3],[1,5],[6,7]]
expected_output =[[1,5],[6,7]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[1, 5], [6, 7]] = Expected: [[1, 5], [6, 7]]
# time: 808 μs (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-5

# %%
intervals = [[1,2],[2,3]]
expected_output = [[1, 3]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[1, 3]] = Expected: [[1, 3]]
# time: 228 μs (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-5

# %%
intervals = [[1,3],[2,5],[4,7]]
expected_output =[[1,7]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[1, 7]] = Expected: [[1, 7]]
# time: 626 μs (started: 2025-10-26 19:23:41 -07:00)

# %% [markdown]
# ### test-6

# %%
intervals = [[]]
expected_output =[[]]

test_solution(intervals, expected_output)
# Out:
# Test PASSED; Actual: [[]] = Expected: [[]]
# time: 303 μs (started: 2025-10-26 19:24:29 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/merge-intervals/submissions/1812733902/
#
#
# <img src="./submission/56-merge-intervals.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
