# %% [markdown]
# # 125. Valid Palindrome
#
# Problem: https://leetcode.com/problems/valid-palindrome/
#
# A phrase is a palindrome if, after converting all uppercase letters into lowercase letters and removing all non-alphanumeric characters, it reads the same forward and backward. Alphanumeric characters include letters and numbers.
#
# Given a string `s`, return `true` if it is a palindrome, or `false` otherwise.
#
# Example 1:
# ``````
# Input: s = "A man, a plan, a canal: Panama"
# Output: true
# Explanation: "amanaplanacanalpanama" is a palindrome.
# ``````
#
# Example 2:
# ``````
# Input: s = "race a car"
# Output: false
# Explanation: "raceacar" is not a palindrome.
# ``````
#
# Example 3:
# ``````
# Input: s = " "
# Output: true
# Explanation: s is an empty string "" after removing non-alphanumeric characters.
# Since an empty string reads the same forward and backward, it is a palindrome.
#  ``````
#
# Constraints:
# - 1 <= s.length <= 2 * 105
# - s consists only of printable ASCII characters.
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `Two Pointers`
# - `String`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   WARNING: The scripts pip, pip3 and pip3.9 are installed in '/Users/krishnam/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed pip-25.2
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 215 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py

import re


class BruteForceSolution:

    def isPalindrome(self, s: str) -> bool:
        # normalize: remove non-alphanumeric and lowercase
        normalized = re.sub(r"[^a-zA-Z0-9]", "", s).lower()

        # build reversed string by concatenation (brute force)
        rev = ""
        for ch in normalized:  # O(n)
            rev = ch + rev

        return normalized == rev
# Out:
# time: 716 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ### BEST

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        s = s.lower()
        left_pointer = 0
        right_pointer = len(s) - 1

        while left_pointer < right_pointer:
            # increase left pointer
            while left_pointer < right_pointer and not s[left_pointer].isalnum():
                left_pointer += 1
            # decrease right pointer
            while left_pointer < right_pointer and not s[right_pointer].isalnum():
                right_pointer -= 1
            # compare
            if s[left_pointer] != s[right_pointer]:
                return False

            left_pointer += 1
            right_pointer -= 1

        return True
# Out:
# time: 373 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
import re


class RegExSolution:

    def isPalindrome(self, s: str) -> bool:

        # normalize: remove non-alphanumeric and lowercase
        normalized = re.sub(r"[^a-zA-Z0-9]", "", s).lower()

        left = 0
        right = len(normalized) - 1
        while left < right:
            if normalized[left] != normalized[right]:
                return False
            left += 1
            right -= 1

        return True  # O(1)
# Out:
# time: 410 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(1)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 8.1 ms (started: 2025-09-24 07:43:32 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(str, expected_output):
    sol = BruteForceSolution()
    actual = sol.isPalindrome(str)

    try:
        if isinstance(expected_output, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 360 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
# Best Solution Test Case
def test_solution(str, expected_output):
    sol = Solution()
    actual = sol.isPalindrome(str)

    try:
        if isinstance(expected_output, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 699 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-1

# %%
str = "A man, a plan, a canal: Panama"
expected_output = True
# Out:
# time: 492 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 858 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 580 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-2

# %%
str = "race a car"
expected_output = False
# Out:
# time: 327 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 208 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 260 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-3

# %%
str = " "
expected_output = True
# Out:
# time: 134 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 153 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 318 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-4

# %%
str = "Was it a car or a cat I saw?"
expected_output = True
# Out:
# time: 483 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 645 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 764 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-5

# %%
str = "tab a cat"
expected_output = False
# Out:
# time: 142 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 552 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 137 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-6

# %%
str = "refer"
expected_output = True
# Out:
# time: 346 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 466 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 808 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-7

# %%
str = "madam"
expected_output = True
# Out:
# time: 125 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 157 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 139 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ### test-8

# %%
str = "level"
expected_output = True
# Out:
# time: 464 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_bruteForce(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 176 μs (started: 2025-09-24 07:43:32 -07:00)

# %%
test_solution(str, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 547 μs (started: 2025-09-24 07:43:32 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/valid-palindrome/submissions/1775658435/
#
# <img src="./submission/125-valid-palindrome.png" />
# <br />
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
