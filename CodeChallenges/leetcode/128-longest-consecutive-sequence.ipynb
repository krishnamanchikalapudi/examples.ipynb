# %% [markdown]
# # 128. Longest Consecutive Sequence
#
# Problem: https://leetcode.com/problems/longest-consecutive-sequence/
#
# Given an unsorted array of integers `nums`, return the length of the longest consecutive elements sequence.
#
# You must write an algorithm that runs in `O(n)` time.
#
#
#
# Example 1:
# ``````
# Input: nums = [100,4,200,1,3,2]
# Output: 4
# Explanation: The longest consecutive elements sequence is [1, 2, 3, 4]. Therefore its length is 4.
# ``````
#
# Example 2:
# ``````
# Input: nums = [0,3,7,2,5,8,4,6,0,1]
# Output: 9
# ``````
#
# Example 3:
# ``````
# Input: nums = [1,0,1,2]
# Output: 3
#  ``````
#
# Constraints:
# - 0 <= nums.length <= 10<sup>5</sup>
# - -10<sup>9</sup> <= nums[i] <= 10<sup>9</sup>
#
# Difficulty: <b>Medium</b>
#
# Tags:
# - `Array`
# - `Hash Table`
# - `Union Find`
#
# ### Companies:
# -

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 128 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class BruteForceSolution:

    def longestConsecutive(self, nums: List[int]) -> int:
        max_len = 0
        n = len(nums)
        for i in range(n):  # Starting index of the subarray O(n)
            for j in range(i, n):  # Ending index of the subarray O(n)
                sub = nums[i : j + 1]
                # Check if sub contains a consecutive sequence
                for k in range(len(sub)):  # O(n)
                    seq = [sub[k]]
                    while seq[-1] + 1 in sub:
                        seq.append(seq[-1] + 1)
                    max_len = max(max_len, len(seq))
        return max_len
# Out:
# time: 589 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n<sup>3</sup>)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ### BEST

# %%
class Solution:

    def longestConsecutive(self, nums: List[int]) -> int:
        longest_seq = 0
        visted_nums_map = {}

        # populate the map with all numbers marked as unvisited
        for num in nums:  # O(n)
            visted_nums_map[num] = False

        for num in nums:  # O(n)
            current_length = 1

            # check the next number in the sequence
            next_num = num + 1
            while next_num in visted_nums_map and not visted_nums_map[next_num]:
                current_length += 1
                visted_nums_map[next_num] = True
                next_num += 1

            # check the previous number in the sequence
            prev_num = num - 1
            while prev_num in visted_nums_map and not visted_nums_map[prev_num]:
                current_length += 1
                visted_nums_map[prev_num] = True
                prev_num -= 1

            longest_seq = max(longest_seq, current_length)

        return longest_seq
# Out:
# time: 400 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 4.62 ms (started: 2025-09-16 18:24:19 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(input, expected_output):
    s = BruteForceSolution()
    actual = s.longestConsecutive(input)

    try:
        if isinstance(expected_output, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 1.01 ms (started: 2025-09-16 18:24:19 -07:00)

# %%
# Best Solution Test Case
def test_solution(input, expected_output):
    s = Solution()
    actual = s.longestConsecutive(input)

    try:
        if isinstance(expected_output, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 648 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# ### test-1

# %%
nums = [100, 4, 200, 1, 3, 2]
expected_output = 4
# Out:
# time: 141 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 144 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 4 = Expected: 4
# time: 123 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# ### test-2

# %%
nums = [0, 3, 7, 2, 5, 8, 4, 6, 0, 1]
expected_output = 9
# Out:
# time: 128 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: 9 = Expected: 9
# time: 201 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 9 = Expected: 9
# time: 260 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# ### test-3

# %%
nums = [1, 0, 1, 2]
expected_output = 3
# Out:
# time: 135 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 177 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 152 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# ### test-4

# %%
nums = [5, 9, 7, 0, 3, 1, 6, 3, 2, 8]
expected_output = 5
# Out:
# time: 197 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_bruteForce(nums, expected_output)
# Out:
# Test PASSED; Actual: 5 = Expected: 5
# time: 203 μs (started: 2025-09-16 18:24:19 -07:00)

# %%
test_solution(nums, expected_output)
# Out:
# Test PASSED; Actual: 5 = Expected: 5
# time: 156 μs (started: 2025-09-16 18:24:19 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/longest-consecutive-sequence/submissions/1773340864/
#
#
# <img src="./submission/128-longest-consecutive-sequence.png" />
# <br />
