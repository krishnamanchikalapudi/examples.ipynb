# %% [markdown]
# # 3. Longest Substring Without Repeating Characters
#
# Problem: https://leetcode.com/problems/longest-substring-without-repeating-characters/
#
# Given a string <code>s</code>, find the length of the longest substring without duplicate characters.
#
# Example 1:
# ``````
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3.
# ``````
#
# Example 2:
# ``````
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# ``````
#
# Example 3:
# ``````
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.
#  ``````
#
# Constraints:
# - 0 <= s.length <= 5 * 104
# - s consists of English letters, digits, symbols and spaces.

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# time: 95.9 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
class BruteForceSolution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        """
        :type nums: s
        :rtype: int
        """
        max_length = 0  # O(1)
        n = len(s)  # O(1)
        for i in range(n):  # O(n)
            for j in range(i + 1, n + 1):  # O(n)
                substring = s[i:j]  # O(1)
                if len(substring) == len(set(substring)):  # O(1)
                    max_length = max(max_length, len(substring))  # O(1)
        return max_length
# Out:
# time: 349 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# The Brute Force solution has a `TIME complexity` of <b>O(n <sup>2</sup>)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ### BEST

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        """
        :type nums: s
        :rtype: int
        """
        char_index_map = {}  # O(n)
        max_length = 0  # O(1)
        start = 0  # O(1)
        for i, char in enumerate(s):  # O(n)
            if char in char_index_map and char_index_map[char] >= start:  # O(1)
                start = char_index_map[char] + 1  # O(1)
            char_index_map[char] = i  # O(1)
            max_length = max(max_length, i - start + 1)  # O(1)
        return max_length
# Out:
# time: 318 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# The Brute Force solution has a `TIME complexity` of <b>O(n <sup>2</sup>)</b> and `SPACE complexity` of <b>O(1)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 12.7 ms (started: 2025-08-13 20:11:58 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(str, expected_output):
    s = BruteForceSolution()
    actual = s.lengthOfLongestSubstring(str)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 302 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
# Best Solution Test Case
def test_solution(str, expected_output):
    s = Solution()
    actual = s.lengthOfLongestSubstring(str)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 547 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# ### test-1

# %%
s = "abcabcbb"
expected_output = 3
# Out:
# time: 190 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
test_bruteForce(s, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 198 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 209 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# ### test-2

# %%
s = "bbbbb"
expected_output = 1
# Out:
# time: 128 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
test_bruteForce(s, expected_output)
# Out:
# Test PASSED; Actual: 1 = Expected: 1
# time: 161 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: 1 = Expected: 1
# time: 123 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# ### test-3

# %%
s = "pwwkew"
expected_output = 3
# Out:
# time: 124 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
test_bruteForce(s, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 151 μs (started: 2025-08-13 20:11:58 -07:00)

# %%
test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 124 μs (started: 2025-08-13 20:11:58 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/longest-substring-without-repeating-characters/submissions/1734422657
# <table>
#  <tr>
# <td><img src="../images/tc-Oof1.png"> </td>
# <td><img src="../images/sc-OofN.png"> </td>
# <tr>
# </table>
