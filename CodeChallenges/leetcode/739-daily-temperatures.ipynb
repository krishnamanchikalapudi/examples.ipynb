# %% [markdown]
# # 739. Daily Temperatures
#
# Problem: https://leetcode.com/problems/daily-temperatures/
#
# Given an array of integers `temperatures` represents the daily temperatures, return an array `answer` such that `answer[i]` is the number of days you have to wait after the i<sup>th</sup> day to get a warmer temperature. If there is no future day for which this is possible, keep `answer[i] == 0` instead.
#
# Example 1:
# ``````
# Input: temperatures = [73,74,75,71,69,72,76,73]
# Output: [1,1,4,2,1,1,0,0]
# ``````
#
# Example 2:
# ``````
# Input: temperatures = [30,40,50,60]
# Output: [1,1,1,0]
# ``````
#
# Example 3:
# ``````
# Input: temperatures = [30,60,90]
# Output: [1,1,0]
#  ``````
#
# Constraints:
# - 1 <= temperatures.length <= 10<sup>5</sup>
# - 30 <= temperatures[i] <= 100
#
# Difficulty: <b>Medium</b>
#
# Tags:
# - `Array`
# - `Stack`
# - `Monotonic Stack`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 165 μs (started: 2025-10-08 20:59:12 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class BruteForceSolution:

    def dailyTemperatures(self, temperatures: List[int]) -> List[int]:
        result = [0] * len(temperatures)  # O(n)
        for i in range(len(temperatures)):
            for j in range(i + 1, len(temperatures)):
                if temperatures[j] > temperatures[i]:
                    result[i] = j - i
                    break

        return result
# Out:
# time: 558 μs (started: 2025-10-08 20:59:12 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n<sup>2</sup>)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:

    def dailyTemperatures(self, temperatures: List[int]) -> List[int]:
         n = len(temperatures)
        result = [0] * n  # O(n)
        stack = []  # stores indices of the temperatures list
       
        for i in range(n - 1, -1, -1):
            # Pop elements from the stack until we find a warmer temperature
            while stack and temperatures[stack[-1]] <= temperatures[i]:
                stack.pop()
            # If the stack is not empty, the top element is the next warmer temperature
            if stack:
                result[i] = stack[-1] - i
            # Push the current index onto the stack
            stack.append(i)

        return result
# Out:
#   File <tokenize>:14
#     result = [0] * n  # O(n)
#     ^
# IndentationError: unindent does not match any outer indentation level
# time: 879 μs (started: 2025-10-08 20:59:12 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# %%
# Brute Force Test Case
def test_bruteForce(inputList, expected_output):
    sol = BruteForceSolution()
    actual = sol.dailyTemperatures(inputList)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )

# %%
# Best Solution Test Case
def test_solution(inputList, expected_output):
    sol = Solution()
    actual = sol.dailyTemperatures(inputList)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )

# %% [markdown]
# ### test-1

# %%
temperatures = [73, 74, 75, 71, 69, 72, 76, 73]
expected_output = [1, 1, 4, 2, 1, 1, 0, 0]

# %%
test_bruteForce(temperatures, expected_output)

# %%
test_solution(temperatures, expected_output)

# %% [markdown]
# ### test-2

# %%
temperatures = [30, 40, 50, 60]
expected_output = [1, 1, 1, 0]

# %%
test_bruteForce(temperatures, expected_output)

# %%
test_solution(temperatures, expected_output)

# %% [markdown]
# ### test-3

# %%
temperatures = [30, 60, 90]
expected_output = [1, 1, 0]

# %%
test_bruteForce(temperatures, expected_output)

# %%
test_solution(temperatures, expected_output)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/daily-temperatures/submissions/1795925946/
#
#
# <img src="./submission/739-daily-temperatures.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
