# %% [markdown]
# # 322. Coin Change
#
# Problem: https://leetcode.com/problems/coin-change/
#
# You are given an integer array `coins` representing coins of different denominations and an integer `amount` representing a total amount of money.
#
# Return the fewest number of `coins` that you need to make up that amount. If that amount of money cannot be made up by any combination of the `coins`, return `-1`.
#
# You may assume that you have an infinite number of each kind of coin.
#
#
# Example 1:
# ``````
# Input: coins = [1,2,5], amount = 11
# Output: 3
# Explanation: 11 = 5 + 5 + 1
# ``````
#
# Example 2:
# ``````
# Input: coins = [2], amount = 3
# Output: -1
# ``````
#
# Example 3:
# ``````
# Input: coins = [1], amount = 0
# Output: 0
#  ``````
#
# Constraints:
# - 1 <= coins.length <= 12
# - 1 <= coins[i] <= 2<sup>31</sup> - 1
# - 0 <= amount <= 10<sup>4</sup>
#
# Difficulty: <b>Medium</b>
#
# Tags:
# - `Array`
# - `Dynamic Programming`
# - `Breadth-First Search`
#
# ### Companies:
# - Walmart
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade --force-reinstall --ignore-installed --no-cache-dir --user pip
# Out:
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.9 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: pip
#   WARNING: The scripts pip, pip3 and pip3.14 are installed in '/Users/krishnam/Library/Python/3.14/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed pip-25.3

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 145 μs (started: 2025-11-07 16:52:28 -08:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### BEST

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:
    def coinChange(self, coins: List[int], amount: int) -> int:
        dp = [amount+1] * (amount+1)
        dp[0] = 0

        for i in range(1, amount+1):
            for coin in coins:
                if coin <= i:
                    dp[i] = min(dp[i], dp[i-coin]+1 )

        if dp[amount] == (amount+1):
            return -1
        
        return dp[amount]
# Out:
# time: 710 μs (started: 2025-11-07 16:52:28 -08:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(?)</b> and `SPACE complexity` of <b>O(?)</b>

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()

# Best Solution Test Case
def test_solution(input, target, expected_output):
    sol = Solution()
    actual = sol.coinChange(input, target)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 6.71 ms (started: 2025-11-07 16:52:28 -08:00)

# %% [markdown]
# ### test-1

# %%
coins = [1,2,5]
amount = 11
expected_output = 3

test_solution(coins, amount, expected_output)
# Out:
# Test PASSED; Actual: 3 = Expected: 3
# time: 338 μs (started: 2025-11-07 16:52:28 -08:00)

# %% [markdown]
# ### test-2

# %%
coins = [2]
amount = 3
expected_output = -1

test_solution(coins, amount, expected_output)
# Out:
# Test PASSED; Actual: -1 = Expected: -1
# time: 212 μs (started: 2025-11-07 16:52:28 -08:00)

# %% [markdown]
# ### test-3

# %%
coins = [1]
amount = 0
expected_output = 0

test_solution(coins, amount, expected_output)
# Out:
# Test PASSED; Actual: 0 = Expected: 0
# time: 1.75 ms (started: 2025-11-07 16:52:28 -08:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/coin-change/submissions/1819201326/
#
#
# <img src="./submission/322-coin-change.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
