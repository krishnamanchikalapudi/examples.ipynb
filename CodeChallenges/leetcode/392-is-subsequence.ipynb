# %% [markdown]
# # 392. Is Subsequence
#
# Problem: https://leetcode.com/problems/is-subsequence/description/
#
# Given two strings `s` and `t`, return `true` if `s` is a subsequence of `t`, or `false` otherwise.
#
# A subsequence of a string is a new string that is formed from the original string by deleting some (can be none) of the characters without disturbing the relative positions of the remaining characters. (i.e., "ace" is a subsequence of "abcde" while "aec" is not).
#
# Example 1:
# ``````
# Input: s = "abc", t = "ahbgdc"
# Output: true
# ``````
#
# Example 2:
# ``````
# Input: s = "axc", t = "ahbgdc"
# Output: false
# ``````
#
# Example 3:
# ``````
# Input: s = "ach", t = "ahbgdc"
# Output: false
# ``````
#
#
# Constraints:
# - 0 <= s.length <= 100
# - 0 <= t.length <= 104
# - s and t consist only of lowercase English letters.
#
# <b>Follow up</b>: Suppose there are lots of incoming s, say `s1, s2, ..., sk` where `k >= 109`, and you want to check one by one to see if t has its subsequence. In this scenario, how would you change your code?
#
#
# ### Companies:
# -

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 149 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class BruteForceSolution:
    def isSubsequence(self, s: str, t: str) -> bool:

        def rec(i, j):
            if i == len(s):
                return True
            if j == len(t):
                return False

            if s[i] == t[j]:
                return rec(i + 1, j + 1)
            return rec(i, j + 1)

        return rec(0, 0)
# Out:
# time: 1 ms (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>

# %% [markdown]
# ### BEST

# %%
class Solution:

    def isSubsequence(self, s: str, t: str) -> bool:
        s_pointer = 0
        t_pointer = 0
        while s_pointer < len(s) and t_pointer < len(t):  # O(n)
            if s[s_pointer] == t[t_pointer]:
                s_pointer += 1
            t_pointer += 1

        return s_pointer == len(s)
# Out:
# time: 564 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(1)</b>
# - n = length of t

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 4.99 ms (started: 2025-09-16 17:33:49 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(source, target, expected_output):
    s = BruteForceSolution()
    actual = s.isSubsequence(source, target)

    try:
        if isinstance(source, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 412 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
# Best Solution Test Case
def test_solution(source, target, expected_output):
    s = Solution()
    actual = s.isSubsequence(source, target)

    try:
        if isinstance(source, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 387 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ### test-1

# %%
s = "abc"
t = "ahbgdc"
expected_output = True
# Out:
# time: 139 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_bruteForce(s, t, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 201 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_solution(s, t, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 149 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ### test-2

# %%
s = "axc"
t = "ahbgdc"
expected_output = False
# Out:
# time: 135 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_bruteForce(s, t, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 152 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_solution(s, t, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 157 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ### test-3

# %%
s = "ach"
t = "ahbgdc"
expected_output = False
# Out:
# time: 136 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_bruteForce(s, t, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 146 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_solution(s, t, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 142 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ### test-4

# %%
s = "node"
t = "nodejs"
expected_output = True
# Out:
# time: 193 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_bruteForce(s, t, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 146 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_solution(s, t, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 162 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ### test-5

# %%
s = "hcd"
t = "ahbgd"
expected_output = False
# Out:
# time: 366 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_bruteForce(s, t, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 642 μs (started: 2025-09-16 17:33:49 -07:00)

# %%
test_solution(s, t, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 152 μs (started: 2025-09-16 17:33:49 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/is-subsequence/submissions/1757671003/
#
#
# <img src="./submission/392-is-subsequence.png" />
# <br />
