# %% [markdown]
# # 20. Valid Parentheses
#
# Problem: https://leetcode.com/problems/valid-parentheses/
#
# Given a string s containing just the characters `(`, `)`, `{`, `}`, `[` and `]`, determine if the input string is valid.
#
# An input string is valid if:
# - Open brackets must be closed by the same type of brackets.
# - Open brackets must be closed in the correct order.
# - Every close bracket has a corresponding open bracket of the same type.
#
# Example 1:
# ``````
# Input: s = "()"
# Output: true
# ``````
#
# Example 2:
# ``````
# Input: s = "()[]{}"
# Output: true
# ``````
#
# Example 3:
# ``````
# Input: s = "(]"
# Output: false
#  ``````
#
# Example 4:
# ``````
# Input: "([])"
# Output: true
#  ``````
#
# Example 5:
# ``````
# Input: s = "([)]"
# Output: false
#  ``````
#
# Constraints:
# - 1 <= s.length <= 10<sup>4</sup>
# - s consists of parentheses only '()[]{}'.
#
# Difficulty: <b>Easy</b>
#
# Tags:
# - `String`
# - `Stack`
#
# ### Companies:
# - ?
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.14/site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 118 μs (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ## Solution

# %%
from typing import Optional
from typing import (
    Dict,
    List,
    Set,
    Tuple,
)  # https://github.com/python/cpython/blob/3.11/Lib/typing.py


class Solution:

    def isValid(self, s: str) -> bool:
        stack = []  # O(1)
        mapping = {")": "(", "}": "{", "]": "["}  # key value pairs O(1)

        for char in s:  # O(n)
            if char in mapping:  
                if stack and stack[-1] == mapping[char]:
                    stack.pop()
                else:
                    return False
            else:
                # if the character is an opening bracket, push it onto the stack.
                stack.append(char)  # O(1)

        if len(stack) == 0:
            return True
    
        return False
# Out:
# time: 1.08 ms (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)</b>
# - Space complexity is O(n) because in the worst case, we might need to push all opening brackets onto the stack.

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()


def test_solution(input, expected_output):
    sol = Solution()
    actual = sol.isValid(input)

    try:
        assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 8.28 ms (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ### test-1

# %%
s = "()"
expected_output = True

test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 181 μs (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ### test-2

# %%
s = "()[]{}"
expected_output = True

test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 11.4 ms (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ### test-3

# %%
s = "(]"
expected_output = False

test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 216 μs (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ### test-4

# %%
s = "([])"
expected_output = True

test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 191 μs (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ### test-5

# %%
s = "([)]"
expected_output = False

test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: False = Expected: False
# time: 769 μs (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ### test-6

# %%
s = "[{()()}()]"
expected_output = True

test_solution(s, expected_output)
# Out:
# Test PASSED; Actual: True = Expected: True
# time: 315 μs (started: 2025-10-22 20:34:00 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/valid-parentheses/submissions/1793777709/
#
#
# <img src="./submission/20-valid-parentheses.png" />
# <br />
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
