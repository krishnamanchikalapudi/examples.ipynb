# %% [markdown]
# # 347. Top K Frequent Elements
#
# Problem: https://leetcode.com/problems/top-k-frequent-elements
#
# Given an integer array `nums` and an integer `k`, return the `k` most <i>frequent elements</i>. You may return the answer in any order.
#
# Example 1:
# ``````
# Input: nums = [1,1,1,2,2,3], k = 2
# Output: [1,2]
# ``````
#
# Example 2:
# ``````
# Input: nums = [1], k = 1
# Output: [1]
# ``````
#
# Constraints:
# - 1 <= nums.length <= 105
# - -104 <= nums[i] <= 104
# - k is in the range [1, the number of unique elements in the array].
# - It is guaranteed that the answer is unique.
#
# Follow up: Your algorithm's time complexity must be better than `O(n log n)`, where n is the array's size.
#
#
# ### Companies:
# - Walmart Labs
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\lib\site-packages (25.2)

# %%
# %pip install -q -U ipython-autotime pytest termcolor

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 0 ns (started: 2025-09-02 17:43:04 -07:00)

# %% [markdown]
# ## Solution

# %% [markdown]
# ### Brute Force

# %%
from typing import List


class BruteForceSolution:
    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        count = {}
        for num in nums:
            count[num] = 1 + count.get(num, 0)

        arr = []
        for num, cnt in count.items():
            arr.append([cnt, num])
        arr.sort()

        res = []
        while len(res) < k:
            res.append(arr.pop()[1])

        return res
# Out:
# time: 0 ns (started: 2025-09-02 17:43:04 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n log n)</b> and `SPACE complexity` of <b>O(n)

# %% [markdown]
# ### BEST

# %%
class Solution:

    def topKFrequent(self, nums: List[int], k: int) -> List[int]:
        freq_hashMap = {}  # val -> index # O(n)
        for i in range(len(nums)):  # O(n)
            num = nums[i]
            if num in freq_hashMap:
                freq_hashMap[num] += 1
            else:
                freq_hashMap[num] = 1

        bucket = [[] for _ in range(len(nums) + 1)]  # O(n)
        # fill the bucket
        for key, freq in freq_hashMap.items():  # O(n)
            bucket[freq].append(key)  # list of index 'freq' = key

        # get the top k frequent elements
        result = []
        for i in reversed(range(len(bucket))):  # O(n)
            if bucket[i]:
                for value in bucket[i]:  # O(n)
                    if len(result) < k:
                        result.append(value)

        return result
# Out:
# time: 0 ns (started: 2025-09-02 17:43:04 -07:00)

# %% [markdown]
# The solution has a `TIME complexity` of <b>O(n)</b> and `SPACE complexity` of <b>O(n)

# %% [markdown]
# ## Test cases

# %%
import unittest
from termcolor import colored

tc = unittest.TestCase()
# Out:
# time: 31 ms (started: 2025-09-02 17:43:04 -07:00)

# %%
# Brute Force Test Case
def test_bruteForce(nums, k, expected_output):
    s = BruteForceSolution()
    actual = s.topKFrequent(nums, k)

    try:
        if isinstance(expected_output, List):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %%
# Best Solution Test Case
def test_solution(nums, k, expected_output):
    s = Solution()
    actual = s.topKFrequent(nums, k)

    try:
        if isinstance(expected_output, list):
            # assert sorted(actual) == sorted(expected_output)
            assert actual.sort() == expected_output.sort()
        else:
            assert actual == expected_output
        print(
            f"Test {colored('PASSED', 'green', attrs=['bold'])}; Actual: {actual} = Expected: {expected_output}"
        )
    except AssertionError:
        print(
            f"Test {colored('FAILED', 'red', attrs=['bold'])}; Actual: {actual} != Expected: {expected_output}"
        )
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %% [markdown]
# ### test-1

# %%
nums = [2, 7, 11, 15]
target = 9
expected_output = [0, 1]
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %%
# test_bruteForce(nums, target, expected_output)
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %%
test_solution(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [2, 7, 11, 15] = Expected: [0, 1]
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %% [markdown]
# ### test-2

# %%
nums = [3, 2, 4]
target = 6
expected_output = [1, 2]
# Out:
# time: 16 ms (started: 2025-09-02 17:43:05 -07:00)

# %%
# test_bruteForce(nums, target, expected_output)
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %%
test_solution(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [2, 3, 4] = Expected: [1, 2]
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %% [markdown]
# ### test-3

# %%
nums = [3, 3]
target = 6
expected_output = [0, 1]
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %%
# test_bruteForce(nums, target, expected_output)
# Out:
# time: 15 ms (started: 2025-09-02 17:43:05 -07:00)

# %%
test_solution(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [3] = Expected: [0, 1]
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %% [markdown]
# ### test-4

# %%
nums = [1, 2, 2, 3, 3, 3]
target = 2
expected_output = [3, 2]
# Out:
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %%
test_solution(nums, target, expected_output)
# Out:
# Test PASSED; Actual: [2, 3] = Expected: [2, 3]
# time: 0 ns (started: 2025-09-02 17:43:05 -07:00)

# %% [markdown]
# ## Summary
#
# My Submission: https://leetcode.com/problems/top-k-frequent-elements/submissions/1757644591
#
#
# <img src="./submission/347-top-k-frequent-elements.png" />
# <br />
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
