# %% [markdown]
# # Data Structures
#
#
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.hackerrank.com/profile/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/-Hackerrank-2EC866?style=for-the-badge&logo=HackerRank&logoColor=white" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %% [markdown]
# ## 1. Arrays

# %% [markdown]
# #### 1.0.1. Create an Array

# %%
arr = [1, 2, 3, 4, 5]

arr
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### 1.0.2. Access elements

# %%
first = arr[0]  # O(1)
first
# Out:
# 1

# %%
last = arr[-1]  # O(1)
last
# Out:
# 5

# %% [markdown]
# #### 1.0.3. Update elements

# %%
arr[2] = 10  # O(1)

arr
# Out:
# [1, 2, 10, 4, 5]

# %% [markdown]
# #### 1.0.4. Add elements

# %%
arr.append(6)  # O(1) amortized

arr
# Out:
# [1, 2, 10, 4, 5, 6]

# %%
arr.insert(1, 7)  # O(n) due to shifting elements

arr
# Out:
# [1, 7, 2, 10, 4, 5, 6]

# %% [markdown]
# #### 1.0.5. Remove elements

# %%
arr.remove(10)  # O(n) due to searching for the element

arr
# Out:
# [1, 7, 2, 4, 5, 6]

# %%
popped = arr.pop()  # O(1)

popped, arr
# Out:
# (6, [1, 7, 2, 4, 5])

# %% [markdown]
# #### 1.0.6. Length of array

# %%
length = len(arr)

length
# Out:
# 5

# %% [markdown]
# #### 1.0.7. Slicing

# %%
sub = arr[1:4]  # O(k) where k is the size of the slice

sub
# Out:
# [7, 2, 4]

# %% [markdown]
# #### 1.0.8. Iteration

# %%
for x in arr:  # O(n)
    print(x)
# Out:
# 1
# 7
# 2
# 4
# 5

# %% [markdown]
# #### 1.0.9. List comprehension

# %%
squared = [x * x for x in arr]  # O(n)
squared
# Out:
# [1, 49, 4, 16, 25]

# %% [markdown]
# #### 1.0.10. Sorting

# %%
arr.sort()  # O(n log n)

arr
# Out:
# [1, 2, 4, 5, 7]

# %%
arr.sort(reverse=True)  # O(n log n)
arr
# Out:
# [7, 5, 4, 2, 1]

# %% [markdown]
# #### 1.0.11. Searching

# %%
exists = 4 in arr  # O(n)
exists
# Out:
# True

# %%
index = arr.index(4)  # O(n) due to searching for the element
index
# Out:
# 2

# %% [markdown]
# #### 1.0.12. Copying

# %%
arr_copy = arr.copy()  # O(n)
arr_copy
# Out:
# [7, 5, 4, 2, 1]

# %% [markdown]
# #### 1.0.13. Extending

# %%
arr.extend([8, 9])  # O(k) where k is the size of the iterable being added
arr
# Out:
# [7, 5, 4, 2, 1, 8, 9]

# %% [markdown]
# #### 1.0.14. Clearing

# %%
arr.clear()  # O(1)
arr
# Out:
# []

# %% [markdown]
# ### 1.2. Two Pointer
#
# Two Pointers is a simple trick where you use two markers (or 'pointers') to look at a list from two places at once — usually the left end and the right end — and move them toward each other until you find the answer.
#
# #### Analogy
# Imagine a row of lockers. One friend stands at locker #1 (left), the other at the last locker (right). They check and then walk toward the middle. By working from both sides, they find what they need faster than one person checking every locker.
#
# #### How it works
# - Put one pointer at the start (left = 0) and one at the end (right = n-1).
# - Compare or combine the two items the pointers point to.
# - Decide which pointer should move (left moves right, or right moves left) based on what you want.
# - Repeat until they meet or you find the answer.
#
# #### Why it’s good
# - Fast: usually O(n) time — you touch each item at most once or a small constant number of times.
# - Memory tiny: O(1) extra space — only a couple of pointers, no big extra arrays.

# %%
arr = [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# #### 1.2.1. Find if a pair sums to target

# %%
def has_pair_with_sum(input, target):
    left, right = 0, len(input) - 1
    while left < right:
        s = input[left] + input[right]
        if s == target:
            return True
        elif s < target:
            left += 1
        else:
            right -= 1
    return False

# %%
has_pair_with_sum(arr, 10)
# Out:
# True

# %% [markdown]
# #### 1.2.2. Reverse an array in-place

# %%
def reverse_array(input):
    left, right = 0, len(input) - 1
    while left < right:
        input[left], input[right] = input[right], input[left]
        left += 1
        right -= 1
    return arr

# %%
reverse_array(arr)
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# #### 1.2.3. Remove duplicates from sorted array

# %%
def remove_duplicates(input):
    if not input:
        return 0
    write = 1
    for read in range(1, len(input)):
        if input[read] != input[read - 1]:
            input[write] = input[read]
            write += 1
    return input[:write]

# %%
sorted_arr = [1, 1, 2, 2, 3, 4, 4, 5]
remove_duplicates(sorted_arr)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### 1.2.4. Partition array (Dutch National Flag)

# %%
def partition(input, pivot):
    left, right = 0, len(input) - 1
    while left <= right:
        if input[left] < pivot:
            left += 1
        elif input[right] >= pivot:
            right -= 1
        else:
            input[left], input[right] = input[right], input[left]
            left += 1
            right -= 1
    return input

# %%
arr2 = [3, 5, 2, 6, 8, 1, 4]
partition(arr2, 5)
# Out:
# [3, 4, 2, 1, 8, 6, 5]

# %% [markdown]
# #### 1.2.5. Move zeros to end

# %%
def move_zeros(input):
    left = 0
    for right in range(len(input)):
        if input[right] != 0:
            input[left], input[right] = input[right], input[left]
            left += 1
    return input

# %%
arr3 = [0, 1, 0, 3, 12]

move_zeros(arr3)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# ### 1.3. Sliding Window
#
# The Sliding Window technique is a way to look at a part of a list (or array) — like a small window that moves step by step — to find something like a sum, average, or pattern.
#
# Think of it as a magnifying glass moving across numbers to focus only on a few at a time.
#
# #### Why we need it
# Sometimes we want to find:
# - The largest or smallest sum of a few numbers in a row.
# - The longest substring without repeating letters.
# - The average of every few numbers.
#
# Instead of checking every possible group (which would be slow), the sliding window moves smoothly — removing the old number and adding the new one — saving time.

# %%
arr = [1, 3, 2, 5, 1, 1, 2, 3]

# %% [markdown]
# #### 1.3.1. Fixed-size sliding window: max sum of subarray of size k

# %%
def max_sum_subarray(input, k):
    window_sum = 0
    max_sum = float("-inf")
    left = 0

    for right in range(len(input)):
        window_sum += input[right]
        if right - left + 1 == k:
            max_sum = max(max_sum, window_sum)
            window_sum -= input[left]
            left += 1

    return max_sum

# %%
 max_sum_subarray(arr, 3)
# Out:
# 10

# %% [markdown]
# #### 1.3.2 Variable-size sliding window: smallest subarray with sum >= target"

# %%
def min_subarray_len(target, input):
    left = 0
    window_sum = 0
    min_len = float("inf")

    for right in range(len(input)):
        window_sum += input[right]
        while window_sum >= target:
            min_len = min(min_len, right - left + 1)
            window_sum -= input[left]
            left += 1
    return min_len if min_len != float("inf") else 0

# %%
min_subarray_len(7, arr)
# Out:
# 2

# %% [markdown]
# #### 1.3.3 Longest substring with at most k distinct elements

# %%
from collections import defaultdict


def longest_substring_k_distinct(s, k):
    left = 0
    max_len = 0
    count = defaultdict(int)
    for right in range(len(s)):
        count[s[right]] += 1
        while len(count) > k:
            count[s[left]] -= 1
            if count[s[left]] == 0:
                del count[s[left]]
            left += 1
        max_len = max(max_len, right - left + 1)
    return max_len

# %%
longest_substring_k_distinct("eceba", 2)
# Out:
# 3

# %% [markdown]
# #### 1.3.4 All subarrays of size k (generator)

# %%
def all_subarrays_of_size_k(input, k):
    for i in range(len(input) - k + 1):
        yield input[i : i + k]

# %%
for sub in all_subarrays_of_size_k(arr, 3):
    print(sub)
# Out:
# [1, 3, 2]
# [3, 2, 5]
# [2, 5, 1]
# [5, 1, 1]
# [1, 1, 2]
# [1, 2, 3]

# %% [markdown]
# #### 1.3.5 Maximum average subarray of size k

# %%
def max_average_subarray(input, k):
    window_sum = sum(input[:k])
    max_avg = window_sum / k
    for i in range(k, len(input)):
        window_sum += input[i] - input[i - k]
        max_avg = max(max_avg, window_sum / k)
    return max_avg

# %%
max_average_subarray(arr, 3)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## 2. Linked Lists

# %% [markdown]
# ### 2.1. Fast and Slow Pointer

# %% [markdown]
# ## 3. Stack
# A Stack is a data structure that works just like a stack of books or plates — you add things on top, and you also remove them from the top.
#
# It follows a rule called LIFO:
# - LIFO = Last In, First Out
#
# That means — the last thing you put in is the first thing that comes out!
#
# #### Stack Operations
# Here are the main actions (operations) you can do on a Stack:
#
# Operation | Meaning | Example
# :--- | :---: | :---
# Push(x) | Add an item to the top | Push(5) → [5]
# Pop() | Remove the top item | Pop() → removes 5
# Peek() / Top() | See what’s on top (without removing) | Top() → 5
# isEmpty() | Check if the stack has no items | True or False

# %% [markdown]
# #### 3.0.1. Create a stack (using list)

# %%
stack = []
stack
# Out:
# []

# %% [markdown]
# #### 3.0.2. Push elements onto stack

# %%
stack.append(1)
stack.append(2)
stack.append(3)

stack
# Out:
# [1, 2, 3]

# %% [markdown]
# #### 3.0.3. Pop element from stack

# %%
top = stack.pop()

top
# Out:
# 3

# %% [markdown]
# #### 3.0.4. Peek at the top element

# %%
if stack:
    peek = stack[-1]
    print(peek)
# Out:
# 2

# %% [markdown]
# #### 3.0.5. Check if stack is empty

# %%
is_empty = len(stack) == 0
is_empty
# Out:
# False

# %% [markdown]
# #### 3.0.6. Stack size

# %%
size = len(stack)
size
# Out:
# 2

# %% [markdown]
# #### 3.0.7. Iterate through stack (from top to bottom)

# %%
for item in reversed(stack):
    print(item)
# Out:
# 2
# 1

# %% [markdown]
# #### 3.0.8. Clear the stack

# %%
stack.clear()
stack
# Out:
# []

# %% [markdown]
# #### 3.0.9. Stack with collections.deque (faster for large stacks)

# %%
from collections import deque

stack = deque()
stack.append(1)
stack.append(2)
stack.pop()

stack
# Out:
# deque([1])

# %% [markdown]
# #### 3.0.10. Custom Stack class (with max size)

# %%
class MyStack:
    def __init__(self, max_size=None):
        self.items = []
        self.max_size = max_size

    def push(self, item):
        if self.max_size is not None and len(self.items) >= self.max_size:
            raise Exception("Stack Overflow")
        self.items.append(item)

    def pop(self):
        if not self.items:
            raise Exception("Stack Underflow")
        return self.items.pop()

    def peek(self):
        if not self.items:
            return None
        return self.items[-1]

    def is_empty(self):
        return len(self.items) == 0

    def size(self):
        return len(self.items)

# %%
s = MyStack(max_size=3)
s.push(10)
s.push(20)

print(s.peek())  # 20",
print(s.pop())  # 20",
print(s.is_empty())  # False
# Out:
# 20
# 20
# False

# %% [markdown]
# ### 3.1. Monotonic Stack
#
# The word monotonic means “always going in one direction” — either up or down, but never both.
#
# So:
# - Monotonic Increasing Stack → elements in stack always go up (from bottom to top).
# - Monotonic Decreasing Stack → elements always go down.
#
# #### Why It’s Useful
# - Monotonic Stacks help solve “Next Greater / Smaller Element” type problems in O(n) time — super efficient!

# %% [markdown]
# ## 4. Queue
# A Queue is a data structure that follows the rule:
# - FIFO = First In, First Out
#
# That means the first thing that goes in is the first thing that comes out —
# just like a line of people waiting their turn at their favorite ice cream shop!
#
# #### Queue Operations
# Operation | What It Does | Example
# :--- | :---: | :---
# Enqueue(x) | Add an item to the back of the queue | Enqueue(5) → [5]
# Dequeue() | Remove the item from the front | Dequeue() → removes 5
# Front() | See the first item (without removing it) | Front() → 5
# isEmpty() | Check if queue is empty | True / False

# %% [markdown]
# #### 4.0.1. Create a queue (using list)

# %%
queue = []

# %% [markdown]
# #### 4.0.2. Enqueue (add to end)

# %%
queue.append(1)
queue.append(2)
queue.append(3)

queue
# Out:
# [1, 2, 3]

# %% [markdown]
# #### 4.0.3. Dequeue (remove from front)

# %%
first = queue.pop(0)
first
# Out:
# 1

# %% [markdown]
# #### 4.0.4. Peek at the front element

# %%
if queue:
    front = queue[0]
    print(front)
# Out:
# 2

# %% [markdown]
# #### 4.0.5. Check if queue is empty

# %%
is_empty = len(queue) == 0
is_empty
# Out:
# False

# %% [markdown]
# #### 4.0.6. Queue size

# %%
size = len(queue)
size
# Out:
# 2

# %% [markdown]
# #### 4.0.7. Iterate through queue (from front to back)

# %%
for item in reversed(stack):
    print(item)
# Out:
# 1

# %% [markdown]
# #### 4.0.8. Clear the queue

# %%
queue.clear()
queue
# Out:
# []

# %% [markdown]
# #### 4.0.9. Queue with collections.deque (efficient for both ends)

# %%
from collections import deque

queue = deque()
queue.append(1)
queue.append(2)
queue.popleft()

queue
# Out:
# deque([2])

# %% [markdown]
# #### 4.0.10. Queue with queue.Queue (thread-safe, for multithreading)

# %%
from queue import Queue

q = Queue()
q.put(10)
q.put(20)
q.put(30)

front = q.get()  # 10
q.empty()  # False
q.qsize()  # 2
# Out:
# 2

# %% [markdown]
# #### 4.0.11. Custom Queue class (with max size)

# %%
class MyQueue:
    def __init__(self, max_size=None):
        self.items = deque()
        self.max_size = max_size

    def enqueue(self, item):
        if self.max_size is not None and len(self.items) >= self.max_size:
            raise Exception("Queue Full")
        self.items.append(item)

    def dequeue(self):
        if not self.items:
            raise Exception("Queue Empty")
        return self.items.popleft()

    def peek(self):
        if not self.items:
            return None
        return self.items[0]

    def is_empty(self):
        return len(self.items) == 0

    def size(self):
        return len(self.items)

# %%
mq = MyQueue(max_size=3)
mq.enqueue(100)
mq.enqueue(200)

print(mq.peek())  # 100
print(mq.dequeue())  # 10
print(mq.is_empty())  # False
# Out:
# 100
# 100
# False

# %% [markdown]
# ## 5. Trees
# - Binary Tree
# - Binary Search Tree
# - Trie
# - Heap (Priority Queue)
# - BFS
# - DFS
# - Backtracking

# %% [markdown]
# ## 6. Graphs
# - Adjacency Matrix
# - Adjacency List
# - BFS
# - DFS
# - Dijkstra's Algorithm
# - A* Search Algorithm
# - Topological Sort
# - Union-Find
# - Bellman-Ford Algorithm
# - Floyd-Warshall Algorithm
# - Kruskal's Algorithm
# - Prim's Algorithm
# - Tarjan's Algorithm
# - Kosaraju's Algorithm
# - Ford-Fulkerson Algorithm
# - Edmonds-Karp Algorithm

# %% [markdown]
# ## 7. Greedy Algorithms
# - Activity Selection Problem
# - Huffman Coding
# - Job Scheduling Problem
# - Kruskal's Algorithm
# - Prim's Algorithm
# - Dijkstra's Algorithm
# - Fractional Knapsack Problem
# - Set Cover Problem
# - Coin Change Problem

# %% [markdown]
# ## 8. Dynamic programming

# %% [markdown]
# <br/><br/>
# <a href="https://leetcode.com/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/dynamic/json?style=for-the-badge&labelColor=black&color=%23ffa116&label=Ranking&query=ranking&url=https%3A%2F%2Fleetcode-badge.vercel.app%2Fapi%2Fusers%2Fkmanchikalapudi&logo=leetcode&logoColor=yellow" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.hackerrank.com/profile/kmanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/-Hackerrank-2EC866?style=for-the-badge&logo=HackerRank&logoColor=white" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/subscribers/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>
