# %% [markdown]
# # 17. Agentic Pattern - Reasoning-Techniques
#
#
# [![Agentic Pattern - Reasoning-Techniques](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.09 ms, sys: 7.4 ms, total: 12.5 ms
# Wall time: 729 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 159 μs (started: 2025-12-04 12:56:03 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 194 μs (started: 2025-12-04 12:56:03 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.82 s (started: 2025-12-04 12:56:03 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Reasoning Techniques")

print(f"{response}")
# Out:
# Agentic pattern-matching (APM) and agentic reasoning are cognitive techniques used to enhance decision-making, problem-solving, and critical thinking. The term "agentic" comes from the concept of agency, which refers to an individual's ability to act independently and make choices.
#
# **What is Agentic Pattern-Matching?**
#
# Agentic pattern-matching (APM) is a reasoning technique that involves recognizing patterns in situations and individuals. It helps users to:
#
# 1. Identify key characteristics or attributes of a situation or person
# 2. Recognize similar patterns or structures in other contexts
# 3. Apply these insights to make informed decisions or predictions
#
# **How does Agentic Pattern-Matching work?**
#
# To use APM, follow these steps:
#
# 1. **Identify the pattern**: Look for distinctive features or characteristics that are relevant to the situation or person.
# 2. **Find similar patterns elsewhere**: Seek out similar patterns or structures in other contexts, such as stories, experiences, or data.
# 3. **Connect the dots**: Use your knowledge and experience to link the patterns together and make predictions or draw conclusions.
#
# **Benefits of Agentic Pattern-Matching**
#
# 1. **Improved decision-making**: APM helps you to recognize patterns that may not be immediately apparent, leading to better decisions.
# 2. **Enhanced critical thinking**: By recognizing patterns, you can identify biases, assumptions, and inconsistencies in your thinking.
# 3. **Increased creativity**: APM encourages you to think outside the box and explore new connections between seemingly unrelated ideas.
#
# **Examples of Agentic Pattern-Matching**
#
# 1. **Detecting trends**: Recognize patterns in data or behavior that indicate a trend or potential issue.
# 2. **Identifying opportunities**: Identify similar patterns in other contexts that suggest potential opportunities for growth or improvement.
# 3. **Analyzing complex systems**: Use APM to break down complex systems into smaller, more manageable parts and identify key patterns.
#
# **Agentic Reasoning**
#
# Agentic reasoning is a broader concept that encompasses not only pattern-matching but also the ability to:
#
# 1. **Ask questions**: Identify areas where you need more information or insight.
# 2. **Seek out diverse perspectives**: Gather multiple viewpoints to inform your thinking.
# 3. **Use analogies and metaphors**: Leverage analogies and metaphors to connect new ideas to existing knowledge.
#
# **Conclusion**
#
# Agentic pattern-matching (APM) is a powerful reasoning technique that can help you recognize patterns, make informed decisions, and think critically. By applying APM in your daily life, you can improve your decision-making, critical thinking, and creativity.
# time: 10.1 s (started: 2025-12-04 12:56:05 -08:00)
