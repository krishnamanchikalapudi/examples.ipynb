# %% [markdown]
# # 18. Agentic Pattern - Guardrails/Safety Patterns
#
#
# [![Agentic Pattern - Guardrails](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.46 ms, sys: 7 ms, total: 12.5 ms
# Wall time: 906 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 161 μs (started: 2025-12-04 12:56:35 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 225 μs (started: 2025-12-04 12:56:35 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.91 s (started: 2025-12-04 12:56:35 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Guardrails and Safety Patterns")

print(f"{response}")
# Out:
# Agentic Pattern, also known as "Guardrails" or "Safety Patterns," is a concept in organizational design and systems thinking that refers to the intentional introduction of constraints, boundaries, or limits into a system to ensure safe operation, stability, and predictability.
#
# The term was coined by Paul N. Edwards and Martyn Evans in their 2006 paper "Complexity and the Problem of Control" (eds.), but it gained popularity through the work of authors like David H. Roberts, who wrote about the concept in his book "Organizational Epistemology: Knowing in Organizations" (2017).
#
# Agentic Pattern is designed to:
#
# 1. **Prevent catastrophic failure**: By introducing boundaries and limits, the system becomes more resilient to extreme or unexpected events that could lead to catastrophic failure.
# 2. **Ensure stability and predictability**: Agentic Patterns help maintain a stable state by constraining the system's behavior, making it easier to anticipate and respond to changes.
# 3. **Support adaptive evolution**: By introducing constraints, the system can adapt and evolve in a controlled manner, rather than being overwhelmed by unpredictable events.
#
# Agentic Patterns can take various forms, such as:
#
# 1. **Boundary-setting**: Establishing clear limits or boundaries within which behavior is allowed or discouraged.
# 2. **Regulatory frameworks**: Implementing rules, regulations, or laws to govern system behavior.
# 3. **Monitoring and control systems**: Using sensors, feedback loops, and control mechanisms to monitor the system's performance and make adjustments as needed.
# 4. **Redundancy and backup systems**: Implementing duplicate or redundant components to ensure continued operation in case of failure.
#
# Examples of Agentic Patterns include:
#
# 1. Air traffic control systems, which use radar, navigation, and communication systems to manage aircraft movement and prevent collisions.
# 2. Financial regulatory frameworks, such as banking regulations and capital requirements, designed to prevent financial crises.
# 3. Healthcare systems, which employ checklists, protocols, and quality control measures to ensure patient safety.
#
# By intentionally introducing Agentic Patterns into a system, organizations can create more stable, predictable, and resilient environments that are better equipped to handle uncertainty and complexity.
# time: 8.09 s (started: 2025-12-04 12:56:37 -08:00)
