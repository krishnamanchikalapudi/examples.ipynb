# %% [markdown]
# # Agentic Pattern - Tool Use (Function Calling)
# The Tool Use pattern, often implemented through a mechanism called Function Calling, enables an agent to interact with external APIs, databases, services, or even execute code.
#
# [![Agentic Pattern - Tool Use presentation](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)
# Requirement already satisfied: pip in /Users/krishnam/Library/Python/3.9/lib/python/site-packages (25.2)
# CPU times: user 5.67 ms, sys: 7.11 ms, total: 12.8 ms
# Wall time: 922 ms
# CPU times: user 5.67 ms, sys: 7.11 ms, total: 12.8 ms
# Wall time: 922 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 160 μs (started: 2025-09-24 17:38:19 -07:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 248 μs (started: 2025-09-24 17:38:19 -07:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.79 s (started: 2025-09-24 17:38:19 -07:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Tool Use")

print(f"{response}")
# Out:
# Agentic Pattern - Tool Use (AP-TU) is a cognitive and motor profile used in autism spectrum disorder (ASD) diagnosis. It was developed by Jean-Luc Picard and colleagues at the International Society for Autism Research (INSAR).
#
# The Agentic Pattern - Tool Use profile assesses an individual's ability to use tools in a more autonomous and agentic way, as opposed to being passively guided or imitative.
#
# In AP-TU, individuals are observed using a tool in a self-directed manner, without explicit instruction or guidance. The goal is to evaluate the person's ability to plan, initiate, and execute the use of the tool independently.
#
# The Agentic Pattern - Tool Use profile consists of several sub-profiles, including:
#
# 1. Initiating: Can the individual start using the tool on their own?
# 2. Planning: Does the individual have a clear plan for how they want to use the tool?
# 3. Executing: Can the individual complete the task using the tool without significant guidance or support?
#
# Scoring is based on the level of autonomy demonstrated by the individual in each sub-profile.
#
# The Agentic Pattern - Tool Use profile is one of several tools used in autism assessment, alongside other profiles such as the Repetitive Behavior Questionnaire (RBQ) and the Restricted and Repetitive Patterns (RRP) scale. By combining multiple profiles, clinicians can gain a more comprehensive understanding of an individual's cognitive and motor abilities.
#
# The AP-TU profile has been shown to be useful in identifying individuals with ASD who may exhibit agentic behaviors, such as self-directed tool use, problem-solving, or even entrepreneurial activities.
#
# Keep in mind that autism assessment is complex, and multiple profiles should not be relied upon for diagnosis. The Agentic Pattern - Tool Use profile is one of many tools used to support comprehensive assessments, but it should be considered in conjunction with other diagnostic criteria and clinical expertise.
# time: 7.51 s (started: 2025-09-24 17:38:21 -07:00)

# %% [markdown]
# ## Define a Tool functions

# %%
from langchain_core.tools import tool as langchain_tool


@langchain_tool
def calculator(expression: str) -> str:
    """Evaluate a simple math expression and return the result."""
    try:
        return str(eval(expression))
    except Exception as e:
        return f"Error: {e}"
# Out:
# time: 18.1 ms (started: 2025-09-24 17:38:28 -07:00)

# %%
@langchain_tool
def get_weather(location: str) -> str:
    """Get the current weather for a location (stub implementation)."""
    fake_weather = {
        "London": "Rainy, 18°C",
        "New York": "Sunny, 25°C",
        "Tokyo": "Cloudy, 22°C",
        "San Francisco": "Cloudy, 20°C",
    }
    return fake_weather.get(location, "Weather data not available")
# Out:
# time: 2.55 ms (started: 2025-09-24 17:38:28 -07:00)

# %%
@langchain_tool
def search_information(query: str) -> str:
    """
    Provides factual information on a given topic. Use this tool to find answers to phrases
    like 'capital of France' or 'weather in London?'.
    """
    print(f"\n--- 🛠️ Tool Called: search_information with query: '{query}' ---")
    simulated_results = {
        "weather in london": "The weather in London is currently cloudy with a temperature of 15°C.",
        "capital of france": "The capital of France is Paris.",
        "population of earth": "The estimated population of Earth is around 8 billion people.",
        "tallest mountain": "Mount Everest is the tallest mountain above sea level.",
        "default": f"Simulated search result for '{query}': No specific information found, but the topic seems interesting.",
    }
    result = simulated_results.get(query.lower(), simulated_results["default"])
    print(f"--- TOOL RESULT: {result} ---")
    return result
# Out:
# time: 2.18 ms (started: 2025-09-24 17:38:28 -07:00)

# %% [markdown]
# ## Bind the Tool to the Model

# %%
# llm_with_tools = [add_two_numbers, multiply, get_weather, search_information]

llm_with_tools = {"calculator": calculator, "get_weather": get_weather}

llm_with_tools
# Out:
# {'calculator': StructuredTool(name='calculator', description='Evaluate a simple math expression and return the result.', args_schema=<class 'langchain_core.utils.pydantic.calculator'>, func=<function calculator at 0x16c5bbe20>),
#  'get_weather': StructuredTool(name='get_weather', description='Get the current weather for a location (stub implementation).', args_schema=<class 'langchain_core.utils.pydantic.get_weather'>, func=<function get_weather at 0x16c7418a0>)}
# time: 1.63 ms (started: 2025-09-24 17:38:29 -07:00)

# %%
from langchain_core.prompts import ChatPromptTemplate

agent_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful AI assistant. You can use tools when needed."),
        ("human", "{input}"),
    ]
)
agent_prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful AI assistant. You can use tools when needed.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])
# time: 40.9 ms (started: 2025-09-24 17:38:29 -07:00)

# %% [markdown]
# ### Router Logic: detect if tool call is required

# %%
import json


def route_tool_call(response: str):
    """
    Very simple parser: expects the model to output JSON like:
    {"tool": "calculator", "args": {"expression": "25*4+10"}}
    If no tool call, return as final answer.
    """
    try:
        data = json.loads(response)
        if "tool" in data and data["tool"] in llm_with_tools:
            tool_func = llm_with_tools[data["tool"]]
            return tool_func.run(**data["args"])
    except Exception:
        return response
    return response
# Out:
# time: 1.47 ms (started: 2025-09-24 17:38:29 -07:00)

# %%
from langchain.schema.runnable import RunnableLambda, RunnablePassthrough

chain = (
    {"input": RunnablePassthrough()}
    | agent_prompt
    | llm_client
    | RunnableLambda(route_tool_call)
)

chain
# Out:
# {
#   input: RunnablePassthrough()
# }
# | ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful AI assistant. You can use tools when needed.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])
# | OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# | RunnableLambda(route_tool_call)
# time: 29.4 ms (started: 2025-09-24 17:38:29 -07:00)

# %% [markdown]
# ## Invoke the Model with a Prompt

# %%
response = chain.invoke("What is the weather in London?")

print(f"{response}")
# Out:
# I'd be happy to help you with that! However, I'm a large language model, I don't have real-time access to current weather conditions. But I can suggest some ways for you to find out the latest weather forecast for London.
#
# You can check online weather websites such as:
#
# * BBC Weather
# * Met Office
# * AccuWeather
#
# These websites provide up-to-date weather forecasts, including temperature, humidity, wind speed, and precipitation. You can also download mobile apps like Dark Sky or Weather Underground that provide hyperlocal weather forecasts.
#
# If you're looking for a more personalized experience, I can suggest some popular weather-related tools and resources:
#
# * Google Search: Type "London weather" in Google to get the latest forecast.
# * Weather Widget: Install a weather widget on your phone or computer to display the current weather conditions.
# * Smart Speaker: Ask your smart speaker like Alexa or Google Assistant about the London weather.
#
# Please let me know if there's anything else I can help you with!
# time: 3.9 s (started: 2025-09-24 17:38:29 -07:00)

# %%
response = chain.invoke(
    "Please calculate 25 * 4 + 10 using the calculator tool. Output JSON with tool call."
)

print(f"{response}")
# Out:
# Here is the calculation in JSON format:
#
# ```
# {
#   "tool": "calculator",
#   "calculation": "25 * 4 + 10"
# }
# ```
#
# And here's the result of the calculation:
#
# ```
# 25 * 4 = 100
# 100 + 10 = 110
# ```
# time: 1.38 s (started: 2025-09-24 17:38:33 -07:00)

# %%
response = chain.invoke(
    "If I bought 100 shares of Apple at $190, and now price is $275, use calculator to compute my profit."
)

print(f"{response}")
# Out:
# To calculate your profit, we'll need to find the difference between the original price and the current price.
#
# Original price = $190
# Current price = $275
#
# Profit = Current price - Original price
# = $275 - $190
# = $85
#
# So, if you bought 100 shares of Apple at $190 and now the price is $275, your profit would be $85 per share.
# time: 1.65 s (started: 2025-09-24 17:38:34 -07:00)
