# %% [markdown]
# # 19. Agentic Pattern - Evaluation and Monitoring
#
#
# [![Agentic Pattern - Evaluation and Monitoring](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.91 ms, sys: 7.12 ms, total: 12 ms
# Wall time: 735 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 138 μs (started: 2025-12-04 12:56:49 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 218 μs (started: 2025-12-04 12:56:49 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.83 s (started: 2025-12-04 12:56:50 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Evaluation and Monitoring")

print(f"{response}")
# Out:
# Agentic Pattern - Evaluation and Monitoring (APEM) is a framework used in project management to evaluate and monitor the progress of projects, particularly those related to IT infrastructure development. It's an extension of the Agile methodology, which emphasizes flexibility, collaboration, and rapid delivery.
#
# The APEM framework focuses on four main areas:
#
# 1. **Agentic Pattern**: This refers to the ability of a system or organization to adapt and respond to changing circumstances, such as changes in requirements, technology advancements, or market trends.
# 2. **Evaluation**: In this context, evaluation involves assessing the effectiveness of the project's progress, identifying risks, and making informed decisions about resource allocation, scope, and timelines.
# 3. **Monitoring**: This step involves regularly tracking the project's progress, detecting anomalies, and taking corrective action to ensure that the project stays on track.
#
# The APEM framework is designed to help organizations:
#
# * Improve the agility and responsiveness of their projects
# * Enhance collaboration and communication among stakeholders
# * Reduce risk and uncertainty
# * Increase transparency and visibility into project progress
#
# Key components of the APEM framework include:
#
# 1. **Project Governance**: Establishing clear goals, objectives, and roles for key stakeholders.
# 2. **Adaptive Planning**: Developing flexible plans that can accommodate changing requirements and priorities.
# 3. **Risk Management**: Identifying, assessing, and mitigating potential risks to project success.
# 4. **Monitoring and Review**: Regularly tracking progress, identifying areas for improvement, and taking corrective action.
#
# By using the APEM framework, organizations can ensure that their projects are agile, adaptable, and responsive to changing circumstances, ultimately leading to better outcomes and increased stakeholder satisfaction.
# time: 6.25 s (started: 2025-12-04 12:56:51 -08:00)
