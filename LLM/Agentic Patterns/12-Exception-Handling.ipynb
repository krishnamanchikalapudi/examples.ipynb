# %% [markdown]
# # 12. Agentic Pattern - Exception Handling and Recovery
#
#
# [![Agentic Pattern - Exception Handling and Recovery](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.78 ms, sys: 6.57 ms, total: 11.4 ms
# Wall time: 727 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 163 μs (started: 2025-12-04 12:52:15 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 170 μs (started: 2025-12-04 12:52:15 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.56 s (started: 2025-12-04 12:52:15 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Exception Handling and Recovery")

print(f"{response}")
# Out:
# Agentic Pattern: Exception Handling and Recovery is a software design pattern that focuses on handling exceptions in a flexible, reactive, and efficient manner. This pattern is also known as the "Agile" approach to exception handling.
#
# **Key Principles:**
#
# 1. **Separation of Concerns**: The agentic pattern separates exception handling from regular program flow. It introduces an extra layer of indirection between the normal execution path and the error-handling mechanism.
# 2. **Reactive Programming**: Instead of blocking or interrupting the main program flow when an exception occurs, the agentic pattern allows for non-blocking error handling. This approach enables the system to continue executing other tasks while handling errors.
# 3. **Async/Await Model**: The agentic pattern often employs asynchronous programming techniques using async/await models. This allows for efficient and scalable error handling in concurrent systems.
# 4. **Proactive Error Handling**: By anticipating potential exceptions, the agentic pattern encourages proactive error handling. This approach reduces the likelihood of unexpected errors and improves overall system reliability.
#
# **Components:**
#
# 1. **Agentic Component**: This is the core component that handles exceptions using the agentic pattern. It's responsible for detecting and reacting to errors in a non-blocking manner.
# 2. **Error Handler**: The error handler is an external component that provides specific error-handling logic, such as logging or alerting mechanisms.
# 3. **Recovery Mechanism**: This component is responsible for implementing recovery strategies when exceptions occur.
#
# **Benefits:**
#
# 1. **Improved System Reliability**: By using the agentic pattern, systems can continue executing tasks even in the presence of errors, reducing downtime and improving overall reliability.
# 2. **Scalability**: The reactive approach enables efficient error handling in concurrent systems, making it easier to scale applications.
# 3. **Flexibility**: The agentic pattern allows for easy integration with other design patterns and frameworks, making it a versatile solution for various use cases.
#
# **Common Use Cases:**
#
# 1. Web Applications
# 2. Microservices Architectures
# 3. Real-time Data Processing Systems
#
# **Example Code (C#):**
# ```csharp
# using System;
# using System.Threading.Tasks;
#
# public class AgenticComponent
# {
#     private readonly ErrorHandler _errorHandler;
#     private readonly RecoveryMechanism _recoveryMechanism;
#
#     public AgenticComponent(ErrorHandler errorHandler, RecoveryMechanism recoveryMechanism)
#     {
#         _errorHandler = errorHandler;
#         _recoveryMechanism = recoveryMechanism;
#     }
#
#     public async Task HandleExceptionAsync(Exception exception)
#     {
#         try
#         {
#             await Task.Delay(10);
#         }
#         catch (Exception ex) when (ex == exception || ex is IOException)
#         {
#             await _errorHandler.HandleErrorAsync(exception);
#             if (_recoveryMechanism != null)
#                 await _recoveryMechanism.RecoverAsync();
#         }
#     }
# }
#
# public class ErrorHandler
# {
#     public async Task HandleErrorAsync(Exception exception)
#     {
#         // Log the error and notify the user
#         Console.WriteLine($"Error: {exception.Message}");
#     }
# }
#
# public class RecoveryMechanism
# {
#     public async Task RecoverAsync()
#     {
#         // Implement recovery logic here
#         Console.WriteLine("Recovery initiated...");
#     }
# }
# ```
# In this example, the `AgenticComponent` handles exceptions using an `async/await` model and delegates error handling to the `ErrorHandler`. The `RecoveryMechanism` is optional but can be used to implement specific recovery strategies.
# time: 13.3 s (started: 2025-12-04 12:52:17 -08:00)
