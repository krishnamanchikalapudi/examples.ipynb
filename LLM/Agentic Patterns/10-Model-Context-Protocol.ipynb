# %% [markdown]
# # 10. Agentic Pattern - Model Context Protocol (MCP)
#
#
# [![Agentic Pattern - Model Context Protocol](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.44 ms, sys: 7.76 ms, total: 13.2 ms
# Wall time: 788 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 138 μs (started: 2025-12-04 12:29:08 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 172 μs (started: 2025-12-04 12:29:08 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 2.24 s (started: 2025-12-04 12:29:08 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - MCP")

print(f"{response}")
# Out:
# Agentic Pattern (MCP) refers to a design pattern used in user experience (UX) and human-computer interaction. It's a behavioral design pattern that aims to facilitate engagement, empowerment, and autonomy for users.
#
# The term "Agentic" comes from the concept of agency, which refers to the capacity of individuals or systems to act independently and make decisions. In UX, agentic patterns are designed to encourage users to take action, make choices, and shape their own experience.
#
# In an agentic pattern, the user is positioned as a proactive agent who can:
#
# 1. Make informed decisions
# 2. Take control of their interactions
# 3. Influence the behavior of the system
#
# Characteristics of agentic patterns include:
#
# 1. Clear goals and intentions
# 2. Transparent feedback mechanisms
# 3. Empowerment through choice and agency
# 4. Autonomy to make decisions
# 5. Feedback loops that allow users to adjust their actions
#
# Examples of agentic patterns in UX design include:
#
# 1. Goal-oriented workflows
# 2. Choice-based interfaces (e.g., multiple options for a user to select from)
# 3. Adaptive systems that learn from user behavior
# 4. Dynamic feedback mechanisms that provide real-time information about the consequences of user actions.
#
# By incorporating agentic patterns, designers can create more engaging and empowering experiences that foster user autonomy, agency, and motivation.
# time: 5.49 s (started: 2025-12-04 12:29:11 -08:00)
