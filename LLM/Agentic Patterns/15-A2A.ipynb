# %% [markdown]
# # 15. Agentic Pattern - Inter-Agent Communication (A2A)
#
#
# [![Agentic Pattern - Inter-Agent Communication](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.53 ms, sys: 6.95 ms, total: 12.5 ms
# Wall time: 903 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 176 μs (started: 2025-12-04 12:54:53 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 194 μs (started: 2025-12-04 12:54:53 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.8 s (started: 2025-12-04 12:54:53 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Inter Agent Communication A2A")

print(f"{response}")
# Out:
# Agentic Pattern - Inter-Agent Communication (A2A) is a concept in multi-agent systems, which refers to the way agents communicate and interact with each other.
#
# In a traditional view of communication, the sender sends a message to the receiver, who then decodes and responds accordingly. However, in A2A, agents are considered "agentic" entities that have their own goals, intentions, and motivations. This means that they do not simply passively receive messages but instead actively engage with each other through communication.
#
# The Agentic Pattern is a design pattern for inter-agent communication that emphasizes the autonomous nature of agents. It aims to create systems where agents can interact with each other in a more natural and human-like way, taking into account their individual goals, intentions, and motivations.
#
# Key characteristics of the Agentic Pattern include:
#
# 1. **Autonomy**: Agents have control over their own actions and decisions.
# 2. **Intentions**: Agents have explicit or implicit intentions that drive their behavior.
# 3. **Goals**: Agents have specific goals that they pursue through communication with other agents.
# 4. **Proactive**: Agents proactively engage with each other, rather than simply reacting to incoming messages.
#
# The Agentic Pattern involves the following components:
#
# 1. **Agent**: An autonomous entity that can act independently and make decisions based on its own goals and intentions.
# 2. **Communication Channel**: A mechanism for agents to exchange information and coordinate their actions.
# 3. **Message Format**: A standardized format for representing messages exchanged between agents.
#
# By using the Agentic Pattern, developers can create multi-agent systems that are more flexible, scalable, and resilient. Agents can adapt to changing circumstances, negotiate with each other, and even exhibit emergent behavior that arises from their collective interactions.
#
# The benefits of the Agentic Pattern include:
#
# 1. **Improved flexibility**: Agents can adjust to new situations and goals.
# 2. **Increased scalability**: Systems can handle a large number of agents.
# 3. **Enhanced autonomy**: Agents make decisions based on their own goals and intentions.
# 4. **Better coordination**: Agents can coordinate their actions more effectively.
#
# However, the Agentic Pattern also presents challenges, such as:
#
# 1. **Complexity**: Developing systems that accommodate multiple agent goals and intentions can be complex.
# 2. **Scalability limitations**: Large-scale systems may become difficult to manage.
# 3. **Autonomy trade-offs**: Balancing autonomy with coordination and control can be a challenge.
#
# Overall, the Agentic Pattern is an important concept in multi-agent systems, as it enables agents to interact with each other in a more natural and adaptive way.
# time: 9.69 s (started: 2025-12-04 12:54:55 -08:00)
