# %% [markdown]
# # 7. Agentic Pattern - Multi Agent
# multiple agents work collaboratively or independently to solve complex tasks by dividing responsibilities among themselves. Each agent can specialize in a particular function, and they communicate and coordinate their actions to achieve a common goal.
#
#
# [![Agentic Pattern - Multi Agent](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.27 ms, sys: 11.4 ms, total: 15.7 ms
# Wall time: 930 ms
# time: 931 ms (started: 2025-12-04 12:26:42 -08:00)

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.27 s (started: 2025-12-04 12:26:42 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 200 μs (started: 2025-12-04 12:26:44 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 16.3 ms (started: 2025-12-04 12:26:44 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Multi Agent")

print(f"{response}")
# Out:
# Agentic pattern in multi-agent systems (MAS) refers to a type of organization structure where each agent has its own goals, motivations, and decision-making processes. In an agentic pattern, agents are autonomous entities that interact with each other and their environment, making decisions based on their individual objectives.
#
# Characteristics of Agentic Pattern:
#
# 1. **Autonomy**: Each agent in the system makes its own decisions and takes actions without external control.
# 2. **Decentralization**: Decision-making authority is distributed among multiple agents, rather than being centralized in a single entity.
# 3. **Competitive**: Agents may compete with each other for resources, attention, or goals.
# 4. **Self-organization**: The system as a whole adapts and evolves through the interactions of individual agents.
#
# Advantages of Agentic Pattern:
#
# 1. **Flexibility**: Agents can adapt to changing conditions and respond to new information in a flexible manner.
# 2. **Scalability**: Agentic systems can handle complex, large-scale problems by dividing them into smaller, manageable tasks.
# 3. **Robustness**: The decentralized nature of agentic systems makes them more resilient to failures or attacks.
#
# Disadvantages of Agentic Pattern:
#
# 1. **Coordination challenges**: Managing the interactions between multiple autonomous agents can be difficult and may lead to conflicts.
# 2. **Lack of global optimization**: Each agent may pursue its own local optimum, leading to suboptimal overall system performance.
# 3. **Vulnerability to manipulation**: If not designed carefully, agentic systems can be vulnerable to manipulation or exploitation by malicious agents.
#
# Applications of Agentic Pattern:
#
# 1. **Swarm intelligence**: Agentic patterns are used in swarm robotics, where multiple robots interact and adapt to their environment to achieve a common goal.
# 2. **Distributed computing**: Agentic systems are used in distributed computing architectures, such as peer-to-peer networks or cloud computing platforms.
# 3. **Artificial life**: Agentic patterns are used in artificial life simulations, where agents evolve and adapt to their environment.
#
# In summary, agentic pattern in multi-agent systems is a decentralized, autonomous approach to organization, where each agent pursues its own goals and decisions. While it offers flexibility and scalability, it also poses challenges in terms of coordination and global optimization.
# time: 8.58 s (started: 2025-12-04 12:26:44 -08:00)
