# %% [markdown]
# # 20. Agentic Pattern - Prioritization
#
#
# [![Agentic Pattern - Prioritization](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.69 ms, sys: 7.14 ms, total: 11.8 ms
# Wall time: 676 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 101 μs (started: 2025-12-04 12:57:08 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 156 μs (started: 2025-12-04 12:57:08 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.56 s (started: 2025-12-04 12:57:08 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Prioritization")

print(f"{response}")
# Out:
# Agentic Pattern - Prioritization is a decision-making framework that helps individuals and teams prioritize their goals, objectives, and tasks in alignment with their values and purpose. It was developed by Dr. Marshall Goldsmith, a renowned management expert and author.
#
# The framework consists of three main components:
#
# 1. **Agentic**: This refers to the ability to take action towards one's goals and values. Agentic individuals are proactive, self-directed, and take responsibility for their actions.
# 2. **Pattern**: This represents the way we respond to situations and challenges. Patterns can be positive or negative, and they influence our behavior and decision-making.
# 3. **Prioritization**: This involves evaluating and ranking tasks, goals, and objectives based on their alignment with one's values and purpose.
#
# The Agentic Pattern - Prioritization framework provides a structured approach to:
#
# * Identify your core values and purpose
# * Recognize patterns that are holding you back or driving positive change
# * Evaluate and prioritize tasks, goals, and objectives in alignment with your values and purpose
# * Make intentional decisions that support your goals and values
#
# The steps involved in the Agentic Pattern - Prioritization framework include:
#
# 1. **Values Clarification**: Identify your core values and purpose.
# 2. **Pattern Recognition**: Recognize patterns that are holding you back or driving positive change.
# 3. **Goal Setting**: Set SMART (Specific, Measurable, Achievable, Relevant, Time-bound) goals that align with your values and purpose.
# 4. **Prioritization**: Evaluate and rank tasks, goals, and objectives based on their alignment with your values and purpose.
# 5. **Action Planning**: Develop an action plan to achieve your prioritized goals.
#
# By using the Agentic Pattern - Prioritization framework, individuals and teams can:
#
# * Increase clarity and focus on their goals and values
# * Improve decision-making and goal achievement
# * Enhance productivity and efficiency
# * Build a sense of purpose and direction
#
# Overall, the Agentic Pattern - Prioritization framework provides a powerful tool for individuals and teams to prioritize their goals, objectives, and tasks in alignment with their values and purpose.
# time: 7.98 s (started: 2025-12-04 12:57:09 -08:00)
