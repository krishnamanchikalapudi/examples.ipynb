# %% [markdown]
# # 6. Agentic Pattern - Planning
# The Planning pattern involves an agent breaking down a complex task into smaller, manageable sub-tasks, creating a structured plan to achieve the overall goal.
#
# [![Agentic Pattern - Planning](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.21 ms, sys: 27.2 ms, total: 32.4 ms
# Wall time: 763 ms
# time: 764 ms (started: 2025-12-04 14:15:22 -08:00)

# %%
# %pip install -U -q langchain langchain-core langchain-ollama crewai crewai-tools ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.46 s (started: 2025-12-04 14:15:23 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 271 μs (started: 2025-12-04 14:15:24 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 15.5 ms (started: 2025-12-04 14:15:24 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Planning")

print(f"{response}")
# Out:
# Agentic Pattern - Planning is a concept in organizational behavior and management that refers to the process of planning and decision-making within an organization. It is based on the idea that individuals within an organization are motivated to achieve their goals and objectives, and that this motivation can be harnessed to drive organizational success.
#
# The Agentic Pattern - Planning approach was first introduced by Robert Quinn and Warren Bennis in their 1986 book "Organizational Design: Theory and Data". It is based on the idea that organizations should focus on developing a culture of self-directed teams, where individuals are empowered to make decisions and take ownership of their work.
#
# The key principles of Agentic Pattern - Planning include:
#
# 1. **Empowerment**: Employees are given the autonomy to make decisions and take action.
# 2. **Self-Directed Teams**: Teams are formed to achieve specific goals and objectives, with a focus on collaboration and shared responsibility.
# 3. **Decentralized Decision-Making**: Decisions are made at the local level, with employees having the authority to make decisions that affect their work.
# 4. **Flexibility and Adaptability**: Organizations adapt quickly to changing circumstances, with a focus on innovation and continuous improvement.
#
# The benefits of Agentic Pattern - Planning include:
#
# 1. **Increased Employee Motivation**: Employees are more engaged and motivated when they have autonomy and ownership over their work.
# 2. **Improved Innovation**: Self-directed teams are better able to identify and capitalize on new opportunities.
# 3. **Faster Response to Change**: Organizations can adapt quickly to changing circumstances, reducing the risk of disruption and increasing resilience.
# 4. **Enhanced Collaboration**: Agentic Pattern - Planning encourages collaboration and teamwork across different departments and levels.
#
# However, there are also potential challenges and limitations to this approach, including:
#
# 1. **Lack of Clear Direction**: Without a clear plan and vision, organizations may struggle to stay focused and aligned.
# 2. **Risk of Chaos**: Without adequate oversight and guidance, self-directed teams can become disorganized and ineffective.
# 3. **Inadequate Resources**: Organizations may need to allocate additional resources to support the growth and development of self-directed teams.
#
# Overall, Agentic Pattern - Planning is a powerful approach to organizational behavior and management that can drive innovation, collaboration, and employee engagement. However, it requires careful planning, leadership, and oversight to ensure its success.
# time: 9.08 s (started: 2025-12-04 14:15:24 -08:00)

# %% [markdown]
# ## Define a clear and focused agent

# %%
from crewai import Agent, Task, Crew, Process
from langchain_ollama.chat_models import ChatOllama

planner_writer_agent = Agent(
    role="Article Planner and Writer",
    goal="Plan and then write a concise, engaging summary on a specified topic.",
    backstory=(
        "You are an expert technical writer and content strategist. "
        "Your strength lies in creating a clear, actionable plan before writing, "
        "ensuring the final summary is both informative and easy to digest."
    ),
    verbose=True,
    llm=llm_client,
)

planner_writer_agent
# Out:
# Error instantiating LLM from unknown object type: Error importing native provider: OPENAI_API_KEY is required
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/crewai/llm.py:392, in LLM.__new__(cls, model, is_litellm, **kwargs)
#     389     kwargs_copy = {k: v for k, v in kwargs.items() if k != "provider"}
#     390     return cast(
#     391         Self,
# --> 392         native_class(model=model_string, provider=provider, **kwargs_copy),
#     393     )
#     394 except NotImplementedError:
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/llms/providers/openai/completion.py:96, in OpenAICompletion.__init__(self, model, api_key, base_url, organization, project, timeout, max_retries, default_headers, default_query, client_params, temperature, top_p, frequency_penalty, presence_penalty, max_tokens, max_completion_tokens, seed, stream, response_format, logprobs, top_logprobs, reasoning_effort, provider, interceptor, **kwargs)
#      86 super().__init__(
#      87     model=model,
#      88     temperature=temperature,
#    (...)
#      93     **kwargs,
#      94 )
# ---> 96 client_config = self._get_client_params()
#      97 if self.interceptor:
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/llms/providers/openai/completion.py:125, in OpenAICompletion._get_client_params(self)
#     124     if self.api_key is None:
# --> 125         raise ValueError("OPENAI_API_KEY is required")
#     127 base_params = {
#     128     "api_key": self.api_key,
#     129     "organization": self.organization,
#    (...)
#     138     "default_query": self.default_query,
#     139 }
#
# ValueError: OPENAI_API_KEY is required
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic Patterns/6-Planning.ipynb Cell 11 line 4
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> from crewai import Agent, Task, Crew, Process
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> from langchain_ollama.chat_models import ChatOllama
# ----> <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> planner_writer_agent = Agent(
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>     role="Article Planner and Writer",
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>     goal="Plan and then write a concise, engaging summary on a specified topic.",
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>     backstory=(
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>         "You are an expert technical writer and content strategist. "
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>         "Your strength lies in creating a clear, actionable plan before writing, "
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>         "ensuring the final summary is both informative and easy to digest."
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a>     ),
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a>     verbose=True,
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a>     llm=ChatOllama(model=my_model_ollama, base_url="http://localhost:11434"),
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> )
#      <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X13sZmlsZQ%3D%3D?line=15'>16</a> planner_writer_agent
#
#     [... skipping hidden 1 frame]
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agent/internal/meta.py:58, in AgentMeta.__new__.<locals>.post_init_setup_with_extensions(self)
#      49 def post_init_setup_with_extensions(self: Any) -> Any:
#      50     """Wrap post_init_setup to apply extensions after initialization.
#      51
#      52     Args:
#    (...)
#      56         The agent instance
#      57     """
# ---> 58     result = original_func(self)
#      60     a2a_value = getattr(self, "a2a", None)
#      61     if a2a_value is not None:
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agent/core.py:225, in Agent.post_init_setup(self)
#     223 @model_validator(mode="after")
#     224 def post_init_setup(self) -> Self:
# --> 225     self.llm = create_llm(self.llm)
#     226     if self.function_calling_llm and not isinstance(
#     227         self.function_calling_llm, BaseLLM
#     228     ):
#     229         self.function_calling_llm = create_llm(self.function_calling_llm)
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/utilities/llm_utils.py:66, in create_llm(llm_value)
#      64 except Exception as e:
#      65     logger.error(f"Error instantiating LLM from unknown object type: {e}")
# ---> 66     raise e
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/utilities/llm_utils.py:53, in create_llm(llm_value)
#      50     base_url: str | None = getattr(llm_value, "base_url", None)
#      51     api_base: str | None = getattr(llm_value, "api_base", None)
# ---> 53     return LLM(
#      54         model=model,
#      55         temperature=temperature,
#      56         max_tokens=max_tokens,
#      57         logprobs=logprobs,
#      58         timeout=timeout,
#      59         api_key=api_key,
#      60         base_url=base_url,
#      61         api_base=api_base,
#      62     )
#      64 except Exception as e:
#      65     logger.error(f"Error instantiating LLM from unknown object type: {e}")
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/llm.py:397, in LLM.__new__(cls, model, is_litellm, **kwargs)
#     395         raise
#     396     except Exception as e:
# --> 397         raise ImportError(f"Error importing native provider: {e}") from e
#     399 # FALLBACK to LiteLLM
#     400 if not LITELLM_AVAILABLE:
#
# ImportError: Error importing native provider: OPENAI_API_KEY is required
# time: 275 ms (started: 2025-12-04 14:15:33 -08:00)

# %% [markdown]
# ## Define a task with a more structured and specific expected output

# %%
topic = "The importance of Reinforcement Learning in AI"
high_level_task = Task(
    description=(
        f"1. Create a bullet-point plan for a summary on the topic: '{topic}'.\n"
        f"2. Write the summary based on your plan, keeping it around 200 words."
    ),
    expected_output=(
        "A final report containing two distinct sections:\n\n"
        "### Plan\n"
        "- A bulleted list outlining the main points of the summary.\n\n"
        "### Summary\n"
        "- A concise and well-structured summary of the topic."
    ),
    agent=planner_writer_agent,
)

high_level_task
# Out:
# Task(description=1. Create a bullet-point plan for a summary on the topic: 'The importance of Reinforcement Learning in AI'.
# 2. Write the summary based on your plan, keeping it around 200 words., expected_output=A final report containing two distinct sections:
#
# ### Plan
# - A bulleted list outlining the main points of the summary.
#
# ### Summary
# - A concise and well-structured summary of the topic.)
# time: 2.74 ms (started: 2025-12-04 13:38:11 -08:00)

# %% [markdown]
# ## Create the crew with a clear process

# %%
crew = Crew(
    agents=[planner_writer_agent],
    tasks=[high_level_task],
    process=Process.sequential,
)

crew
# Out:
# Provider List: https://docs.litellm.ai/docs/providers
# Crew(id=598f6b54-0d1d-459d-8a6a-f488760987ce, process=Process.sequential, number_of_agents=1, number_of_tasks=1)
# time: 8.9 ms (started: 2025-12-04 13:38:47 -08:00)

# %% [markdown]
# ## Execute the task

# %%
result = crew.kickoff()

result
# Out:
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#
# # Agent: Article Planner and Writer
# ## Task: 1. Create a bullet-point plan for a summary on the topic: 'The importance of Reinforcement Learning in AI'.
# 2. Write the summary based on your plan, keeping it around 200 words.
# ERROR:root:LiteLLM call failed: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=llama3.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# Provider List: https://docs.litellm.ai/docs/providers
#
#  Error during LLM call: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=llama3.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
#  An unknown error occurred. Please check the details below.
#  Error details: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=llama3.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic Patterns/6-Planning.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> result = crew.kickoff()
#       <a href='vscode-notebook-cell:/Users/krishnam/Documents/GitHub-KM/examples.ipynb/LLM/Agentic%20Patterns/6-Planning.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> result
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/crew.py:663, in kickoff(self, inputs)
#     650             CrewTrainingHandler(filename).save_trained_data(
#     651                 agent_id=str(agent.role),
#     652                 trained_data=result.model_dump(),
#     653             )
#     655     crewai_event_bus.emit(
#     656         self,
#     657         CrewTrainCompletedEvent(
#    (...)
#     661         ),
#     662     )
# --> 663 except Exception as e:
#     664     crewai_event_bus.emit(
#     665         self,
#     666         CrewTrainFailedEvent(error=str(e), crew_name=self.name),
#     667     )
#     668     self._logger.log("error", f"Training failed: {e}", color="red")
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/crew.py:775, in _run_sequential_process(self)
#     770         crewai_event_bus.emit(
#     771             self,
#     772             CrewKickoffFailedEvent(error=str(e), crew_name=self.name),
#     773         )
#     774         raise
# --> 775     finally:
#     776         detach(token)
#     778 def kickoff_for_each(
#     779     self, inputs: list[dict[str, Any]]
#     780 ) -> list[CrewOutput | CrewStreamingOutput]:
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/crew.py:878, in _execute_tasks(self, tasks, start_index, was_replayed)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/task.py:347, in execute_sync(self, agent, context, tools)
#     345 self._guardrails = guardrails
#     346 if self._guardrails:
# --> 347     self.guardrail = None
#     348     self._guardrail = None
#     350 return self
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/task.py:491, in _execute_core(self, agent, context, tools)
#     482     threading.Thread(
#     483         daemon=True,
#     484         target=self._execute_task_async,
#     485         args=(agent, context, tools, future),
#     486     ).start()
#     487     return future
#     489 def _execute_task_async(
#     490     self,
# --> 491     agent: BaseAgent | None,
#     492     context: str | None,
#     493     tools: list[Any] | None,
#     494     future: Future[TaskOutput],
#     495 ) -> None:
#     496     """Execute the task asynchronously with context handling."""
#     497     result = self._execute_core(agent, context, tools)
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/task.py:411, in _execute_core(self, agent, context, tools)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agent.py:387, in execute_task(self, task, context, tools)
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agent.py:363, in execute_task(self, task, context, tools)
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agent.py:459, in _execute_without_timeout(self, task_prompt, task)
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/crew_agent_executor.py:123, in invoke(self, inputs)
#     121 self.stop = stop_words
#     122 self.max_iter = max_iter
# --> 123 self.callbacks = callbacks or []
#     124 self._printer: Printer = Printer()
#     125 self.tools_handler = tools_handler
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/crew_agent_executor.py:112, in invoke(self, inputs)
#      70 def __init__(
#      71     self,
#      72     llm: BaseLLM,
#    (...)
#      89     response_model: type[BaseModel] | None = None,
#      90 ) -> None:
#      91     """Initialize executor.
#      92
#      93     Args:
#      94         llm: Language model instance.
#      95         task: Task to execute.
#      96         crew: Crew instance.
#      97         agent: Agent to execute.
#      98         prompt: Prompt templates.
#      99         max_iter: Maximum iterations.
#     100         tools: Available tools.
#     101         tools_names: Tool names string.
#     102         stop_words: Stop word list.
#     103         tools_description: Tool descriptions.
#     104         tools_handler: Tool handler instance.
#     105         step_callback: Optional step callback.
#     106         original_tools: Original tool list.
#     107         function_calling_llm: Optional function calling LLM.
#     108         respect_context_window: Respect context limits.
#     109         request_within_rpm_limit: RPM limit check function.
#     110         callbacks: Optional callbacks list.
#     111         response_model: Optional Pydantic model for structured outputs.
# --> 112     """
#     113     self._i18n: I18N = get_i18n()
#     114     self.llm = llm
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/crew_agent_executor.py:208, in _invoke_loop(self)
#     207 def _invoke_loop(self) -> AgentFinish:
# --> 208     """Execute agent loop until completion.
#     209
#     210     Returns:
#     211         Final answer from the agent.
#     212     """
#     213     formatted_answer = None
#     214     while not isinstance(formatted_answer, AgentFinish):
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/crew_agent_executor.py:155, in _invoke_loop(self)
#     152 @property
#     153 def use_stop_words(self) -> bool:
#     154     """Check to determine if stop words are being used.
# --> 155
#     156     Returns:
#     157         bool: True if tool should be used or not.
#     158     """
#     159     return self.llm.supports_stop_words() if self.llm else False
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/utilities/agent_utils.py:157, in get_llm_response(llm, messages, callbacks, printer)
#     154 else:
#     155     assistant_message = i18n.errors("force_final_answer")
# --> 157 messages.append(format_message_for_llm(assistant_message, role="assistant"))
#     159 # Perform one more LLM call to get the final answer
#     160 answer = llm.call(
#     161     messages,
#     162     callbacks=callbacks,
#     163 )
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/utilities/agent_utils.py:148, in get_llm_response(llm, messages, callbacks, printer)
#     124 def handle_max_iterations_exceeded(
#     125     formatted_answer: AgentAction | AgentFinish | None,
#     126     printer: Printer,
#    (...)
#     130     callbacks: list[TokenCalcHandler],
#     131 ) -> AgentFinish:
#     132     """Handles the case when the maximum number of iterations is exceeded. Performs one more LLM call to get the final answer.
#     133
#     134     Args:
#    (...)
#     143         AgentFinish with the final answer after exceeding max iterations.
#     144     """
#     145     printer.print(
#     146         content="Maximum iterations reached. Requesting final answer.",
#     147         color="yellow",
# --> 148     )
#     150     if formatted_answer and hasattr(formatted_answer, "text"):
#     151         assistant_message = (
#     152             formatted_answer.text + f"\n{i18n.errors('force_final_answer')}"
#     153         )
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/llm.py:890, in call(self, messages, tools, callbacks, available_functions)
#     888 if last_chunk:
#     889     choices = None
# --> 890     if isinstance(last_chunk, dict) and "choices" in last_chunk:
#     891         choices = last_chunk["choices"]
#     892     elif hasattr(last_chunk, "choices"):
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/llm.py:729, in _handle_non_streaming_response(self, params, callbacks, available_functions)
#     724 accumulated_tool_args: defaultdict[int, AccumulatedToolArgs] = defaultdict(
#     725     AccumulatedToolArgs
#     726 )
#     728 # --- 2) Make sure stream is set to True and include usage metrics
# --> 729 params["stream"] = True
#     730 params["stream_options"] = {"include_usage": True}
#     732 try:
#     733     # --- 3) Process each chunk in the stream
#
# File /opt/homebrew/lib/python3.11/site-packages/litellm/utils.py:1255, in client.<locals>.wrapper(*args, **kwargs)
#    1251 if logging_obj:
#    1252     logging_obj.failure_handler(
#    1253         e, traceback_exception, start_time, end_time
#    1254     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1255 raise e
#
# File /opt/homebrew/lib/python3.11/site-packages/litellm/utils.py:1133, in client.<locals>.wrapper(*args, **kwargs)
#    1131         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1132 # MODEL CALL
# -> 1133 result = original_function(*args, **kwargs)
#    1134 end_time = datetime.datetime.now()
#    1135 if "stream" in kwargs and kwargs["stream"] is True:
#
# File /opt/homebrew/lib/python3.11/site-packages/litellm/main.py:3216, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3213     return response
#    3214 except Exception as e:
#    3215     ## Map to OpenAI Exception
# -> 3216     raise exception_type(
#    3217         model=model,
#    3218         custom_llm_provider=custom_llm_provider,
#    3219         original_exception=e,
#    3220         completion_kwargs=args,
#    3221         extra_kwargs=kwargs,
#    3222     )
#
# File /opt/homebrew/lib/python3.11/site-packages/litellm/main.py:1031, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1029     model = deployment_id
#    1030     custom_llm_provider = "azure"
# -> 1031 model, custom_llm_provider, dynamic_api_key, api_base = get_llm_provider(
#    1032     model=model,
#    1033     custom_llm_provider=custom_llm_provider,
#    1034     api_base=api_base,
#    1035     api_key=api_key,
#    1036 )
#    1038 if (
#    1039     provider_specific_header is not None
#    1040     and provider_specific_header["custom_llm_provider"] == custom_llm_provider
#    1041 ):
#    1042     headers.update(provider_specific_header["extra_headers"])
#
# File /opt/homebrew/lib/python3.11/site-packages/litellm/litellm_core_utils/get_llm_provider_logic.py:360, in get_llm_provider(model, custom_llm_provider, api_base, api_key, litellm_params)
#     358 except Exception as e:
#     359     if isinstance(e, litellm.exceptions.BadRequestError):
# --> 360         raise e
#     361     else:
#     362         error_str = (
#     363             f"GetLLMProvider Exception - {str(e)}\n\noriginal model: {model}"
#     364         )
#
# File /opt/homebrew/lib/python3.11/site-packages/litellm/litellm_core_utils/get_llm_provider_logic.py:337, in get_llm_provider(model, custom_llm_provider, api_base, api_key, litellm_params)
#     335     error_str = f"LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model={model}\n Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers"
#     336     # maps to openai.NotFoundError, this is raised when openai does not recognize the llm
# --> 337     raise litellm.exceptions.BadRequestError(  # type: ignore
#     338         message=error_str,
#     339         model=model,
#     340         response=httpx.Response(
#     341             status_code=400,
#     342             content=error_str,
#     343             request=httpx.Request(method="completion", url="https://github.com/BerriAI/litellm"),  # type: ignore
#     344         ),
#     345         llm_provider="",
#     346     )
#     347 if api_base is not None and not isinstance(api_base, str):
#     348     raise Exception(
#     349         "api base needs to be a string. api_base={}".format(api_base)
#     350     )
#
# BadRequestError: litellm.BadRequestError: LLM Provider NOT provided. Pass in the LLM provider you are trying to call. You passed model=llama3.2
#  Pass model as E.g. For 'Huggingface' inference endpoints pass in `completion(model='huggingface/starcoder',..)` Learn more: https://docs.litellm.ai/docs/providers
# time: 761 ms (started: 2025-12-04 13:39:25 -08:00)
