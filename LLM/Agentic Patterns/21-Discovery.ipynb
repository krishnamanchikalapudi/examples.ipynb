# %% [markdown]
# # 21. Agentic Pattern - Exploration and Discovery
#
#
# [![Agentic Pattern - Exploration and Discovery](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 6.44 ms, sys: 8.16 ms, total: 14.6 ms
# Wall time: 863 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 163 μs (started: 2025-12-04 12:57:28 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 184 μs (started: 2025-12-04 12:57:28 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.89 s (started: 2025-12-04 12:57:28 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Exploration and Discovery")

print(f"{response}")
# Out:
# Agentic Pattern - Exploration and Discovery (APED) is a framework for understanding human behavior, motivation, and decision-making. Developed by psychologist Edward Deci, APED is part of the Self-Determination Theory (SDT), which posits that humans have innate psychological needs, including autonomy, competence, and relatedness.
#
# In the context of APED, Exploration and Discovery refers to a pattern of behavior characterized by:
#
# 1. **Curiosity**: A desire to explore new experiences, learn, and discover.
# 2. **Experimentation**: Trying out new approaches, methods, or techniques to gather information and insights.
# 3. **Risk-taking**: Taking calculated risks to test hypotheses, challenge assumptions, or push boundaries.
# 4. **Innovative thinking**: Generating novel solutions, ideas, or perspectives.
#
# APED is often associated with individuals who are:
#
# 1. Innovators: Creating new products, services, or processes.
# 2. Entrepreneurs: Starting new businesses or ventures.
# 3. Researchers: Conducting experiments, collecting data, and analyzing results.
# 4. Artists: Exploring new mediums, techniques, or styles.
#
# Characteristics of APED include:
#
# * **Intrinsic motivation**: Engaging in activities for personal satisfaction, interest, or enjoyment.
# * **Focus on process over outcome**: Emphasizing the journey, learning, and growth, rather than just the end result.
# * **Emphasis on exploration and discovery**: Seeking to understand, learn, and discover new things.
#
# APED is a powerful framework for understanding human behavior, as it highlights the importance of autonomy, curiosity, and innovation in driving motivation, creativity, and progress.
# time: 6.11 s (started: 2025-12-04 12:57:30 -08:00)
