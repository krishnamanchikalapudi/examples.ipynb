# %% [markdown]
# # 14. Agentic Pattern - Knowledge Retrieval (RAG)
#
#
# [![Agentic Pattern - Knowledge Retrieval](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.88 ms, sys: 6.93 ms, total: 11.8 ms
# Wall time: 734 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 280 μs (started: 2025-12-04 12:53:13 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 209 μs (started: 2025-12-04 12:53:13 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.74 s (started: 2025-12-04 12:53:13 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Knowledge Retrieval RAG")

print(f"{response}")
# Out:
# Agentic Pattern - Knowledge Retrieval (RAG) is a hybrid search model that combines the strengths of different search techniques to improve knowledge retrieval and information retrieval. The term "Agentic" refers to the agent-based approach, where an intelligent agent plays a central role in searching for relevant documents.
#
# Here's a brief overview of the Agentic Pattern - Knowledge Retrieval (RAG) system:
#
# **Key Components:**
#
# 1. **Agent**: An autonomous entity that searches for relevant documents based on user queries.
# 2. **Knowledge Graph**: A graph-based representation of knowledge, where entities and their relationships are stored.
# 3. **Document Retrieval System**: A system that retrieves documents from a large corpus based on the query.
#
# **How it Works:**
#
# 1. The agent receives a user query and performs a relevance ranking of the top N documents in the document retrieval system.
# 2. The agent then uses the knowledge graph to identify relevant entities, concepts, and relationships related to the query.
# 3. Based on this analysis, the agent selects a subset of documents from the retrieved list that are most likely to contain relevant information.
# 4. The final step is to retrieve these selected documents and rank them based on their relevance.
#
# **Advantages:**
#
# 1. **Improved Relevance**: RAG combines the strengths of different search techniques, including document retrieval, knowledge graph-based ranking, and relevance feedback.
# 2. **Efficient Search**: By selecting a subset of relevant documents from the retrieved list, RAG reduces the number of irrelevant documents that need to be processed.
#
# **Applications:**
#
# 1. **Information Retrieval Systems**: RAG can be used as a hybrid search engine to improve the accuracy and efficiency of information retrieval systems.
# 2. **Question Answering Systems**: RAG can be applied to question answering systems to retrieve relevant answers from a large corpus.
# 3. **Knowledge Graph-based Search**: RAG can be used in knowledge graph-based search systems, where entities and relationships are stored in a graph database.
#
# **Challenges:**
#
# 1. **Scalability**: Integrating multiple search techniques and handling large-scale datasets can be challenging.
# 2. **Complexity**: The agent-based approach requires careful tuning of parameters and balancing different factors to achieve optimal performance.
#
# Overall, the Agentic Pattern - Knowledge Retrieval (RAG) system has shown promising results in improving knowledge retrieval and information retrieval tasks. However, further research is needed to address the challenges and scalability issues associated with this hybrid search model.
# time: 9.25 s (started: 2025-12-04 12:53:15 -08:00)
