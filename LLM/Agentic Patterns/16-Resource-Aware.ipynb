# %% [markdown]
# # 16. Agentic Pattern - Resource-Aware Optimization
#
#
# [![Agentic Pattern - Resource-Aware Optimization](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.39 ms, sys: 7.99 ms, total: 13.4 ms
# Wall time: 872 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 181 μs (started: 2025-12-04 12:55:38 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 192 μs (started: 2025-12-04 12:55:38 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.76 s (started: 2025-12-04 12:55:38 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Resource-Aware Optimization")

print(f"{response}")
# Out:
# Agentic Pattern - Resource-Aware Optimization (APO) is a software optimization technique that focuses on optimizing resource allocation in complex systems. The term "agentic" refers to the autonomous nature of the optimization process, where the system itself takes an active role in identifying and addressing bottlenecks or inefficiencies.
#
# In APO, the goal is to optimize the allocation of resources (such as CPU, memory, or network bandwidth) within a system to achieve maximum performance, efficiency, or responsiveness. The technique involves modeling the system's behavior and identifying areas where optimization can be applied to improve resource utilization.
#
# Key characteristics of Agentic Pattern - Resource-Aware Optimization:
#
# 1. **Autonomous optimization**: The system itself identifies and addresses bottlenecks or inefficiencies without human intervention.
# 2. **Resource-awareness**: The optimization process takes into account the available resources within the system, such as CPU, memory, or network bandwidth.
# 3. **Dynamic adaptation**: APO adapts to changing system conditions, such as changes in workload or resource availability, to optimize performance.
# 4. **Self-organization**: The system organizes itself to optimize resource allocation, without relying on external control mechanisms.
#
# APO can be applied to various domains, including:
#
# 1. **Cloud computing**: Optimizing resource allocation in cloud-based systems to improve scalability and efficiency.
# 2. **Distributed systems**: Improving resource utilization in distributed systems, such as data centers or networks.
# 3. **Real-time systems**: Enhancing performance and responsiveness in real-time systems that require predictable and efficient resource allocation.
#
# APO techniques can include:
#
# 1. **Model predictive control (MPC)**: Using machine learning algorithms to predict system behavior and optimize resource allocation based on predicted outcomes.
# 2. **Reinforcement learning**: Training agents to learn optimal strategies for resource allocation through trial and error.
# 3. **Game theory**: Analyzing and optimizing resource allocation as a game between competing agents or interests.
#
# The benefits of Agentic Pattern - Resource-Aware Optimization include:
#
# 1. **Improved system performance**: Optimized resource allocation can lead to improved system responsiveness, throughput, and overall efficiency.
# 2. **Increased scalability**: APO enables systems to adapt to changing demands without compromising performance.
# 3. **Enhanced reliability**: Self-organizing systems can detect and respond to failures or anomalies more effectively.
#
# However, APO also presents challenges, such as:
#
# 1. **Complexity**: Optimizing complex systems with multiple interacting components requires advanced modeling and analysis techniques.
# 2. **Uncertainty**: Uncertainty in system behavior or external factors can impact the effectiveness of APO.
# 3. **Energy efficiency**: Optimizing resource allocation while minimizing energy consumption remains an open challenge.
#
# Overall, Agentic Pattern - Resource-Aware Optimization represents a promising approach to improving system performance and efficiency by harnessing the power of autonomous optimization and self-organization.
# time: 10.5 s (started: 2025-12-04 12:55:40 -08:00)
