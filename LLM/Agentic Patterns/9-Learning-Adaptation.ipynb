# %% [markdown]
# # 9. Agentic Pattern - Learning and Adaptation
# This section explores how AI agents can learn from their experiences and adapt their behavior over time. It covers techniques such as reinforcement learning, online learning, and adaptive algorithms that enable agents to improve their performance based on feedback and changing environments.
#
#
# [![Agentic Pattern - Learning and Adaptation](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.1 ms, sys: 12 ms, total: 16.1 ms
# Wall time: 920 ms
# time: 921 ms (started: 2025-12-04 12:28:36 -08:00)

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.25 s (started: 2025-12-04 12:28:37 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 194 μs (started: 2025-12-04 12:28:39 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 16.4 ms (started: 2025-12-04 12:28:39 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Learning and Adaptation")

print(f"{response}")
# Out:
# Agentic Pattern Learning (APL) refers to a learning approach that focuses on the development of autonomy, self-regulation, and metacognition. It's an educational philosophy that emphasizes the importance of student agency, choice, and self-directed learning.
#
# Key characteristics of Agentic Pattern Learning:
#
# 1. **Student Autonomy**: Students are given choices and freedom to make decisions about their learning, such as selecting topics, pace, or assessment methods.
# 2. **Self-Regulation**: Students take responsibility for managing their own learning, including setting goals, monitoring progress, and adjusting strategies as needed.
# 3. **Metacognition**: Students develop an awareness of their own thought processes, learning habits, and cognitive biases to improve their self-directed learning.
# 4. **Pattern Recognition**: Students learn to identify patterns in their own learning experiences, identifying what works and what doesn't, and adapting their approach accordingly.
# 5. **Adaptation**: Students are encouraged to reflect on their learning and make adjustments to their approach as needed.
#
# The Agentic Pattern Learning framework is based on the following principles:
#
# 1. **Pattern recognition**: Recognize patterns in one's own learning experiences to identify areas for improvement.
# 2. **Reflection**: Reflect on one's learning to understand what works and what doesn't.
# 3. **Adaptation**: Adapt one's approach to learning based on reflections and new information.
# 4. **Self-regulation**: Take responsibility for managing one's own learning, including setting goals, monitoring progress, and adjusting strategies as needed.
#
# The benefits of Agentic Pattern Learning include:
#
# 1. Increased student autonomy and motivation
# 2. Improved self-directed learning skills
# 3. Enhanced metacognitive awareness
# 4. Better academic performance
# 5. Increased creativity and innovation
#
# Agentic Pattern Learning is often used in educational settings to support students' social-emotional development, academic achievement, and career readiness. It's a flexible and adaptive approach that can be tailored to meet the diverse needs of learners.
# time: 7.37 s (started: 2025-12-04 12:28:39 -08:00)
