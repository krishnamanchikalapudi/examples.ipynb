# %% [markdown]
# # 11. Agentic Pattern - Goal Setting and Monitoring
#
#
# [![Agentic Pattern - Goal Setting and Monitoring](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 5.75 ms, sys: 8.55 ms, total: 14.3 ms
# Wall time: 990 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 124 μs (started: 2025-12-04 12:51:23 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 150 μs (started: 2025-12-04 12:51:23 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.99 s (started: 2025-12-04 12:51:23 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Goal Setting and monitoring")

print(f"{response}")
# Out:
# Agentic Pattern refers to a specific approach to goal setting and monitoring that emphasizes personal responsibility, autonomy, and self-directed progress. It's a pattern of behavior characterized by:
#
# 1. **Self-assessment**: Identifying personal strengths, weaknesses, values, and motivations to inform goal setting.
# 2. **Clear goals**: Setting specific, measurable, achievable, relevant, and time-bound (SMART) goals that align with one's values and priorities.
# 3. **Personal accountability**: Taking ownership of progress, making decisions, and taking action towards achieving goals.
# 4. **Self-monitoring**: Regularly tracking progress, identifying areas for improvement, and adjusting goals as needed.
# 5. **Adaptability**: Being open to change, flexibility, and learning from failures.
#
# Agentic Pattern is often associated with the concept of "self-efficacy," which refers to an individual's confidence in their ability to succeed in achieving their goals. This pattern is characterized by a sense of agency, self-motivation, and intrinsic interest in goal pursuit.
#
# Key elements of Agentic Pattern:
#
# 1. **Autonomy**: The individual takes ownership of their goals and decisions.
# 2. **Self-regulation**: The individual regulates their own behavior, emotions, and thoughts to achieve goals.
# 3. **Flexibility**: The individual is open to adjusting goals, plans, and strategies as needed.
#
# Benefits of Agentic Pattern:
#
# 1. **Increased motivation**: When individuals are engaged in goal pursuit, they experience increased motivation and intrinsic interest.
# 2. **Improved self-efficacy**: Developing a sense of agency and confidence in one's abilities enhances self-efficacy.
# 3. **Enhanced personal growth**: Embracing an agentic pattern fosters continuous learning, adaptation, and improvement.
#
# In contrast to other patterns, such as Directive Pattern (e.g., hierarchical or prescriptive approach), Agentic Pattern emphasizes individual autonomy and agency in goal setting and monitoring.
# time: 9.97 s (started: 2025-12-04 12:51:25 -08:00)
