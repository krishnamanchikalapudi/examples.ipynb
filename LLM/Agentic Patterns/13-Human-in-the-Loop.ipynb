# %% [markdown]
# # 13. Agentic Pattern - Human-in-the-Loop (HITL)
#
#
# [![Agentic Pattern - Human in the Loop](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.82 ms, sys: 6.81 ms, total: 11.6 ms
# Wall time: 727 ms

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# time: 172 μs (started: 2025-12-04 12:52:40 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 469 μs (started: 2025-12-04 12:52:40 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 1.82 s (started: 2025-12-04 12:52:40 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Human-in-the-Loop")

print(f"{response}")
# Out:
# Agentic Pattern - Human-in-the-Loop (HIP) is a design approach that involves collaborating with humans to create systems that are more transparent, explainable, and trustworthy. The term "Human-in-the-Loop" refers to the idea of involving humans in the decision-making process, rather than relying solely on algorithms or machines.
#
# In an Agentic Pattern - HIP system, humans play a crucial role in the decision-making process, while technology provides support and assistance. This approach recognizes that humans have unique strengths, such as creativity, empathy, and critical thinking, which are essential for making complex decisions.
#
# Key characteristics of Agentic Pattern - Human-in-the-Loop systems:
#
# 1. **Human-centered design**: The system is designed with human needs and values in mind.
# 2. **Collaboration between humans and machines**: Humans work together with technology to make decisions.
# 3. **Transparency and explainability**: The system provides clear explanations for its decisions and actions.
# 4. **Trustworthiness**: The system is designed to be reliable, secure, and trustworthy.
#
# Benefits of Agentic Pattern - Human-in-the-Loop systems:
#
# 1. **Improved decision-making**: Humans bring unique perspectives and strengths to the decision-making process.
# 2. **Increased trust**: By involving humans in the decision-making process, trust is built and maintained.
# 3. **Enhanced explainability**: The system provides clear explanations for its decisions, making it more transparent.
# 4. **Better handling of complex situations**: Humans can handle complex, ambiguous, or uncertain situations that may be difficult for machines to resolve.
#
# Agentic Pattern - Human-in-the-Loop systems have applications in various domains, such as:
#
# 1. Healthcare: Collaborative decision-making in healthcare, where humans and machines work together to make decisions about patient care.
# 2. Education: Personalized learning platforms that involve human teachers and mentors in the decision-making process.
# 3. Finance: Robust decision-making systems that incorporate human judgment and expertise.
#
# By incorporating Agentic Pattern - Human-in-the-Loop design principles, organizations can create more effective, efficient, and trustworthy systems that leverage the strengths of both humans and machines.
# time: 7.95 s (started: 2025-12-04 12:52:42 -08:00)
