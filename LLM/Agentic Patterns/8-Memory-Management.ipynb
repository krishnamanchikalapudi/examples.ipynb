# %% [markdown]
# # 8. Agentic Pattern - Memory Management
# The Memory Management pattern involves an agent effectively storing, retrieving, and utilizing information from its interactions to enhance its performance over time. This pattern is crucial for creating agents that can learn from past experiences and adapt their behavior accordingly.
#
#
# [![Agentic Pattern - Memory Management](https://img.youtube.com/vi/?/0.jpg)](https://youtu.be/?)
#
# <br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://www.youtube.com/@dayonedev" target="_new">
#   <img align="center" src="https://img.shields.io/youtube/channel/views/UCiLziPE9aPxCouSsX0lJ--A" />
# </a>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <a href="https://linkedin.com/in/krishnamanchikalapudi" target="_new">
#   <img align="center" src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" />
# </a>
# <br/>

# %%
# %%time
import warnings
warnings.filterwarnings("ignore")

# !python3 -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (25.3)
# CPU times: user 4.17 ms, sys: 10.9 ms, total: 15 ms
# Wall time: 930 ms
# time: 931 ms (started: 2025-12-04 12:27:25 -08:00)

# %%
# %pip install -U -q langchain langchain-core langchain-ollama ipython-autotime --use-deprecated=legacy-resolver

# %load_ext autotime
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.3 s (started: 2025-12-04 12:27:25 -08:00)

# %% [markdown]
# ## Variables

# %%
my_model_ollama = "llama3.2"
# Out:
# time: 197 μs (started: 2025-12-04 12:27:27 -08:00)

# %% [markdown]
# ## Initialize OLLAM service
# OLLAMA inference client is initialized to interact with the OLLAMA API for generating responses from the specified model.

# %%
from langchain_ollama.llms import OllamaLLM

llm_client = OllamaLLM(
    model=my_model_ollama,
    base_url="http://localhost:11434",
    headers={"Content-Type": "application/json"},
    stream=True,
    temperature=0.7,
)


llm_client
# Out:
# OllamaLLM(model='llama3.2', temperature=0.7, base_url='http://localhost:11434')
# time: 16.3 ms (started: 2025-12-04 12:27:27 -08:00)

# %% [markdown]
# ### TEST llm_client with a simple prompt

# %%
response = llm_client.invoke("What is Agentic Pattern - Memory Management")

print(f"{response}")
# Out:
# Agentic Pattern, also known as "Agentic" or "Self-Aware", is a memory management pattern used in various programming languages and frameworks. It's designed to help developers manage memory more efficiently, especially when working with large datasets.
#
# **Key Characteristics:**
#
# 1. **Pre-allocate memory**: Instead of allocating memory on the fly using `new` or `malloc`, the Agentic Pattern pre-allocates a fixed amount of memory for each object.
# 2. **Object pooling**: When an object is no longer needed, it's returned to the pool and reused instead of being garbage collected.
# 3. **Efficient memory reuse**: By reusing existing objects, the pattern minimizes the overhead of creating new objects.
#
# **Benefits:**
#
# 1. **Memory efficiency**: Reduces memory fragmentation and allocations, leading to improved performance and reduced memory usage.
# 2. **Faster object creation**: Since objects are pre-allocated and reused, there's no need to wait for garbage collection or worry about running out of memory.
# 3. **Simplified code**: The Agentic Pattern can simplify code by reducing the number of allocations and deallocations.
#
# **Example Use Cases:**
#
# 1. **Database connections**: In a database-driven application, using an agentic pattern can help manage connections more efficiently.
# 2. **Image processing**: When working with large image datasets, pre-allocating memory for images can reduce memory fragmentation and improve performance.
# 3. **Game development**: In games, object pooling can be used to optimize the creation and destruction of game objects.
#
# **Example Code (in C++):**
# ```cpp
# // Agentic Pattern example in C++
# class Agent {
# public:
#     // Constructor that allocates fixed amount of memory
#     Agent(size_t size) : data_(new char[size]) {}
#
#     // Destructor that reuses allocated memory
#     ~Agent() { delete[] data_; }
#
# private:
#     char* data_;
# };
#
# // Usage example
# int main() {
#     Agent agent(1024); // Pre-allocates 1KB of memory
#
#     // Use the agent...
#     std::cout << "Using pre-allocated memory" << std::endl;
#
#     return 0;
# }
# ```
# Note that this is a simplified example, and in practice, you may need to consider additional factors like object cloning, serialization, and thread safety when implementing an agentic pattern.
# time: 8.9 s (started: 2025-12-04 12:27:27 -08:00)
